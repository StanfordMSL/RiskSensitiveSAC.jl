# %%
using Revise

ENV["PYCALL_JL_RUNTIME_PYTHON"] = Sys.which("python")
using FileIO
using JLD2
using RiskSensitiveSAC
# Out:
# ┌ Info: Number of Julia Thread(s): 1
# └ @ RiskSensitiveSAC /home/haruki/Documents/2020-21_Autumn/RiskSensitiveSAC.jl/src/RiskSensitiveSAC.jl:39
# ┌ Info: CUDA Device: GeForce RTX 2080 Ti
# └ @ RiskSensitiveSAC /home/haruki/Documents/2020-21_Autumn/RiskSensitiveSAC.jl/src/RiskSensitiveSAC.jl:40
# ┌ Info: Python executable used by PyCall: /home/haruki/Documents/2020-21_Autumn/RiskSensitiveSAC.jl/env_trajectron++/bin/python3.6
# └ @ RiskSensitiveSAC /home/haruki/Documents/2020-21_Autumn/RiskSensitiveSAC.jl/src/RiskSensitiveSAC.jl:41

# %%
include("$(@__DIR__)/../scripts/default_params/params_data_oracle.jl");

include("$(@__DIR__)/../scripts/parameter_setup.jl");

# %%
scene_loader, controller, w_init, measurement_schedule, target_trajectory, target_speed =
controller_setup(scene_param,
                 predictor_param,
                 prediction_device=prediction_device,
                 cost_param=cost_param,
                 cnt_param=cnt_param,
                 dtc=dtc,
                 ego_pos_init_vec=ego_pos_init_vec,
                 ego_pos_goal_vec=ego_pos_goal_vec,
                 target_speed=target_speed,
                 sim_horizon=sim_horizon,
                 verbose=true);
# Out:
# Scene Mode: data
# Prediction Mode: oracle
# Deterministic Prediction: true
# Loaded evaluation data from /home/haruki/Documents/2020-21_Autumn/RiskSensitiveSAC.jl/Trajectron-plus-plus/experiments/processed/eth_test.pkl
# Looking at the eth_test.pkl sequence, data_id 0, start_idx 905

# %%
result, ~, ~ = evaluate(scene_loader, controller, w_init, ego_pos_goal_vec,
                  target_speed, measurement_schedule, target_trajectory,
                  pos_error_replan, nominal_control=false);
# Out:
# ┌ Warning: Time 0.00 [sec]: SAC computation took 29.344 [sec], which exceeds the maximum computation time allowed.
# └ @ RiskSensitiveSAC /home/haruki/Documents/2020-21_Autumn/RiskSensitiveSAC.jl/src/rs_sac_controller.jl:731
# ┌ Warning: Time 0.00 [sec]: This evaluation iteration took 0.41 [sec], which exceeds dtc.
# └ @ RiskSensitiveSAC /home/haruki/Documents/2020-21_Autumn/RiskSensitiveSAC.jl/src/evaluation.jl:249
# ┌ Warning: Time 0.40 [sec]: This evaluation iteration took 0.316 [sec], which exceeds dtc.
# └ @ RiskSensitiveSAC /home/haruki/Documents/2020-21_Autumn/RiskSensitiveSAC.jl/src/evaluation.jl:249

# %%
display_log(result.log)
# Out:
# Time 0.00 [sec]: New prediction is available to the controller.
# Time 0.00 [sec]: New SAC control computation is scheduled.
# Time 0.00 [sec]: New SAC control is available to the controller.
# Time 0.00 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.02 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.04 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.06 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.08 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.10 [sec]: New SAC control computation is scheduled.
# Time 0.10 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.12 [sec]: New SAC control is available to the controller.
# Time 0.12 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.14 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.16 [sec]: Control: [1.6287916506553634e-20, 1.51085851030075e-6] is applied to the system.
# Time 0.18 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.20 [sec]: New SAC control computation is scheduled.
# Time 0.20 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.22 [sec]: New SAC control is available to the controller.
# Time 0.22 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.24 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.26 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.28 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.30 [sec]: New SAC control computation is scheduled.
# Time 0.30 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.32 [sec]: New SAC control is available to the controller.
# Time 0.32 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.34 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.36 [sec]: Control: [2.1136440513794608e-20, -2.1399498564278474e-6] is applied to the system.
# Time 0.38 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.40 [sec]: New measurement is obtained.
# Time 0.40 [sec]: New prediction is scheduled.
# Time 0.40 [sec]: New SAC control computation is scheduled.
# Time 0.40 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.42 [sec]: New prediction is available to the controller.
# Time 0.42 [sec]: New SAC control is available to the controller.
# Time 0.42 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.44 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.46 [sec]: Control: [7.729823494136182e-21, 1.2132405800002743e-6] is applied to the system.
# Time 0.48 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.50 [sec]: New SAC control computation is scheduled.
# Time 0.50 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.52 [sec]: New SAC control is available to the controller.
# Time 0.52 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.54 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.56 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.58 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.60 [sec]: New SAC control computation is scheduled.
# Time 0.60 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.62 [sec]: New SAC control is available to the controller.
# Time 0.62 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.64 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.66 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.68 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.70 [sec]: New SAC control computation is scheduled.
# Time 0.70 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.72 [sec]: New SAC control is available to the controller.
# Time 0.72 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.74 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.76 [sec]: Control: [1.5456941081771485e-21, 2.1517275854421314e-6] is applied to the system.
# Time 0.78 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.80 [sec]: New measurement is obtained.
# Time 0.80 [sec]: New prediction is scheduled.
# Time 0.80 [sec]: New SAC control computation is scheduled.
# Time 0.80 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.82 [sec]: New prediction is available to the controller.
# Time 0.82 [sec]: New SAC control is available to the controller.
# Time 0.82 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.84 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.86 [sec]: Control: [1.076536086327181e-21, -1.0875702400880982e-6] is applied to the system.
# Time 0.88 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.90 [sec]: New SAC control computation is scheduled.
# Time 0.90 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.92 [sec]: New SAC control is available to the controller.
# Time 0.92 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.94 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.96 [sec]: Control: [4.985796891716136e-20, -7.408499982375361e-7] is applied to the system.
# Time 0.98 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.00 [sec]: New SAC control computation is scheduled.
# Time 1.00 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.02 [sec]: New SAC control is available to the controller.
# Time 1.02 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.04 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.06 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.08 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.10 [sec]: New SAC control computation is scheduled.
# Time 1.10 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.12 [sec]: New SAC control is available to the controller.
# Time 1.12 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.14 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.16 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.18 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.20 [sec]: New measurement is obtained.
# Time 1.20 [sec]: New prediction is scheduled.
# Time 1.20 [sec]: New SAC control computation is scheduled.
# Time 1.20 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.22 [sec]: New prediction is available to the controller.
# Time 1.22 [sec]: New SAC control is available to the controller.
# Time 1.22 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.24 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.26 [sec]: Control: [1.4494754604850793e-25, -1.688957240730815e-6] is applied to the system.
# Time 1.28 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.30 [sec]: New SAC control computation is scheduled.
# Time 1.30 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.32 [sec]: New SAC control is available to the controller.
# Time 1.32 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.34 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.36 [sec]: Control: [5.267308277847102e-24, 3.047704808523122e-7] is applied to the system.
# Time 1.38 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.40 [sec]: New SAC control computation is scheduled.
# Time 1.40 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.42 [sec]: New SAC control is available to the controller.
# Time 1.42 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.44 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.46 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.48 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.50 [sec]: New SAC control computation is scheduled.
# Time 1.50 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.52 [sec]: New SAC control is available to the controller.
# Time 1.52 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.54 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.56 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.58 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.60 [sec]: New measurement is obtained.
# Time 1.60 [sec]: New prediction is scheduled.
# Time 1.60 [sec]: New SAC control computation is scheduled.
# Time 1.60 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.62 [sec]: New prediction is available to the controller.
# Time 1.62 [sec]: New SAC control is available to the controller.
# Time 1.62 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.64 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.66 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.68 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.70 [sec]: New SAC control computation is scheduled.
# Time 1.70 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.72 [sec]: New SAC control is available to the controller.
# Time 1.72 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.74 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.76 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.78 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.80 [sec]: New SAC control computation is scheduled.
# Time 1.80 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.82 [sec]: New SAC control is available to the controller.
# Time 1.82 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.84 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.86 [sec]: Control: [0.4055895507335663, -0.9140552878379822] is applied to the system.
# Time 1.88 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.90 [sec]: New SAC control computation is scheduled.
# Time 1.90 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.92 [sec]: New SAC control is available to the controller.
# Time 1.92 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.94 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.96 [sec]: Control: [0.06854164600372314, -0.16668571531772614] is applied to the system.
# Time 1.98 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.00 [sec]: New measurement is obtained.
# Time 2.00 [sec]: New prediction is scheduled.
# Time 2.00 [sec]: New SAC control computation is scheduled.
# Time 2.00 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.02 [sec]: New prediction is available to the controller.
# Time 2.02 [sec]: New SAC control is available to the controller.
# Time 2.02 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.04 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.06 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.08 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.10 [sec]: New SAC control computation is scheduled.
# Time 2.10 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.12 [sec]: New SAC control is available to the controller.
# Time 2.12 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.14 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.16 [sec]: Control: [0.7989884614944458, -1.833471417427063] is applied to the system.
# Time 2.18 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.20 [sec]: New SAC control computation is scheduled.
# Time 2.20 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.22 [sec]: New SAC control is available to the controller.
# Time 2.22 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.24 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.26 [sec]: Control: [-0.8060910701751709, 1.8303598165512085] is applied to the system.
# Time 2.28 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.30 [sec]: New SAC control computation is scheduled.
# Time 2.30 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.32 [sec]: New SAC control is available to the controller.
# Time 2.32 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.34 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.36 [sec]: Control: [-0.046199068427085876, 0.10635430365800858] is applied to the system.
# Time 2.38 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.40 [sec]: New measurement is obtained.
# Time 2.40 [sec]: New prediction is scheduled.
# Time 2.40 [sec]: New SAC control computation is scheduled.
# Time 2.40 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.42 [sec]: New prediction is available to the controller.
# Time 2.42 [sec]: New SAC control is available to the controller.
# Time 2.42 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.44 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.46 [sec]: Control: [-0.029159117490053177, 0.06882020831108093] is applied to the system.
# Time 2.48 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.50 [sec]: New SAC control computation is scheduled.
# Time 2.50 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.52 [sec]: New SAC control is available to the controller.
# Time 2.52 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.54 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.56 [sec]: Control: [0.8080821633338928, -1.8294817209243774] is applied to the system.
# Time 2.58 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.60 [sec]: New SAC control computation is scheduled.
# Time 2.60 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.62 [sec]: New SAC control is available to the controller.
# Time 2.62 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.64 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.66 [sec]: Control: [-0.8074375987052917, 1.8297662734985352] is applied to the system.
# Time 2.68 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.70 [sec]: New SAC control computation is scheduled.
# Time 2.70 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.72 [sec]: New SAC control is available to the controller.
# Time 2.72 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.74 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.76 [sec]: Control: [-0.05612964928150177, 0.13188226521015167] is applied to the system.
# Time 2.78 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.80 [sec]: New measurement is obtained.
# Time 2.80 [sec]: New prediction is scheduled.
# Time 2.80 [sec]: New SAC control computation is scheduled.
# Time 2.80 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.82 [sec]: New prediction is available to the controller.
# Time 2.82 [sec]: New SAC control is available to the controller.
# Time 2.82 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.84 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.86 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.88 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.90 [sec]: New SAC control computation is scheduled.
# Time 2.90 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.92 [sec]: New SAC control is available to the controller.
# Time 2.92 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.94 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.96 [sec]: Control: [0.817422091960907, -1.8253276348114014] is applied to the system.
# Time 2.98 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.00 [sec]: New SAC control computation is scheduled.
# Time 3.00 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.02 [sec]: New SAC control is available to the controller.
# Time 3.02 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.04 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.06 [sec]: Control: [-0.8175369501113892, 1.825276255607605] is applied to the system.
# Time 3.08 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.10 [sec]: New SAC control computation is scheduled.
# Time 3.10 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.12 [sec]: New SAC control is available to the controller.
# Time 3.12 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.14 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.16 [sec]: Control: [-0.09047344326972961, 0.21386371552944183] is applied to the system.
# Time 3.18 [sec]: Control: [0.03347209841012955, -0.07594816386699677] is applied to the system.
# Time 3.20 [sec]: New measurement is obtained.
# Time 3.20 [sec]: New prediction is scheduled.
# Time 3.20 [sec]: New SAC control computation is scheduled.
# Time 3.20 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.22 [sec]: New prediction is available to the controller.
# Time 3.22 [sec]: New SAC control is available to the controller.
# Time 3.22 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.24 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.26 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.28 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.30 [sec]: New SAC control computation is scheduled.
# Time 3.30 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.32 [sec]: New SAC control is available to the controller.
# Time 3.32 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.34 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.36 [sec]: Control: [0.8402227759361267, -1.814945101737976] is applied to the system.
# Time 3.38 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.40 [sec]: New SAC control computation is scheduled.
# Time 3.40 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.42 [sec]: New SAC control is available to the controller.
# Time 3.42 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.44 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.46 [sec]: Control: [-0.7480719089508057, 1.5911484956741333] is applied to the system.
# Time 3.48 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.50 [sec]: New SAC control computation is scheduled.
# Time 3.50 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.52 [sec]: New SAC control is available to the controller.
# Time 3.52 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.54 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.56 [sec]: Control: [-0.1128111183643341, 0.2444942593574524] is applied to the system.
# Time 3.58 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.60 [sec]: New measurement is obtained.
# Time 3.60 [sec]: New prediction is scheduled.
# Time 3.60 [sec]: New SAC control computation is scheduled.
# Time 3.60 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.62 [sec]: New prediction is available to the controller.
# Time 3.62 [sec]: New SAC control is available to the controller.
# Time 3.62 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.64 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.66 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.68 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.70 [sec]: New SAC control computation is scheduled.
# Time 3.70 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.72 [sec]: New SAC control is available to the controller.
# Time 3.72 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.74 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.76 [sec]: Control: [0.8537256717681885, -1.808632731437683] is applied to the system.
# Time 3.78 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.80 [sec]: New SAC control computation is scheduled.
# Time 3.80 [sec]: Control: [-1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 3.82 [sec]: New SAC control is available to the controller.
# Time 3.82 [sec]: Control: [-1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 3.84 [sec]: Control: [-1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 3.86 [sec]: Control: [4.277096271514893, 2.5896811485290527] is applied to the system.
# Time 3.88 [sec]: Control: [-1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 3.90 [sec]: New SAC control computation is scheduled.
# Time 3.90 [sec]: Control: [-1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 3.92 [sec]: New SAC control is available to the controller.
# Time 3.92 [sec]: Control: [-1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 3.94 [sec]: Control: [3.052262544631958, -3.960264205932617] is applied to the system.
# Time 3.96 [sec]: Control: [3.052262544631958, -3.960264205932617] is applied to the system.
# Time 3.98 [sec]: Control: [-1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 4.00 [sec]: New measurement is obtained.
# Time 4.00 [sec]: New prediction is scheduled.
# Time 4.00 [sec]: New SAC control computation is scheduled.
# Time 4.00 [sec]: Control: [-1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 4.02 [sec]: New prediction is available to the controller.
# Time 4.02 [sec]: New SAC control is available to the controller.
# Time 4.02 [sec]: Control: [-1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 4.04 [sec]: Control: [-1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 4.06 [sec]: Control: [1.0952929258346558, 1.6734195947647095] is applied to the system.
# Time 4.08 [sec]: Control: [-1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 4.10 [sec]: New SAC control computation is scheduled.
# Time 4.10 [sec]: Control: [-1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 4.12 [sec]: New SAC control is available to the controller.
# Time 4.12 [sec]: Control: [-1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 4.14 [sec]: Control: [-1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 4.16 [sec]: Control: [-1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 4.18 [sec]: Control: [1.7578113079071045, -3.59306263923645] is applied to the system.
# Time 4.20 [sec]: New SAC control computation is scheduled.
# Time 4.20 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.22 [sec]: New SAC control is available to the controller.
# Time 4.22 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.24 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.26 [sec]: Control: [0.7725341320037842, 1.8447740077972412] is applied to the system.
# Time 4.28 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.30 [sec]: New SAC control computation is scheduled.
# Time 4.30 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.32 [sec]: New SAC control is available to the controller.
# Time 4.32 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.34 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.36 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.38 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.40 [sec]: New measurement is obtained.
# Time 4.40 [sec]: New prediction is scheduled.
# Time 4.40 [sec]: New SAC control computation is scheduled.
# Time 4.40 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.42 [sec]: New prediction is available to the controller.
# Time 4.42 [sec]: New SAC control is available to the controller.
# Time 4.42 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.44 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.46 [sec]: Control: [-0.38127586245536804, -1.9633208513259888] is applied to the system.
# Time 4.48 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.50 [sec]: New SAC control computation is scheduled.
# Time 4.50 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.52 [sec]: New SAC control is available to the controller.
# Time 4.52 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.54 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.56 [sec]: Control: [-0.9110586643218994, -3.894864797592163] is applied to the system.
# Time 4.58 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.60 [sec]: New SAC control computation is scheduled.
# Time 4.60 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.62 [sec]: New SAC control is available to the controller.
# Time 4.62 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.64 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.66 [sec]: Control: [0.9735483527183533, 3.8797168731689453] is applied to the system.
# Time 4.68 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.70 [sec]: New SAC control computation is scheduled.
# Time 4.70 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.72 [sec]: New SAC control is available to the controller.
# Time 4.72 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.74 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.76 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.78 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.80 [sec]: New measurement is obtained.
# Time 4.80 [sec]: New prediction is scheduled.
# Time 4.80 [sec]: New SAC control computation is scheduled.
# Time 4.80 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.82 [sec]: New prediction is available to the controller.
# Time 4.82 [sec]: New SAC control is available to the controller.
# Time 4.82 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.84 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.86 [sec]: Control: [-0.8414653539657593, -1.8143693208694458] is applied to the system.
# Time 4.88 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.90 [sec]: New SAC control computation is scheduled.
# Time 4.90 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.92 [sec]: New SAC control is available to the controller.
# Time 4.92 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.94 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.96 [sec]: Control: [-2.023332118988037, -4.572321891784668] is applied to the system.
# Time 4.98 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.00 [sec]: New SAC control computation is scheduled.
# Time 5.00 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.02 [sec]: New SAC control is available to the controller.
# Time 5.02 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.04 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.06 [sec]: Control: [1.5007543563842773, 4.769458770751953] is applied to the system.
# Time 5.08 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.10 [sec]: New SAC control computation is scheduled.
# Time 5.10 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.12 [sec]: New SAC control is available to the controller.
# Time 5.12 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.14 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.16 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.18 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.20 [sec]: New measurement is obtained.
# Time 5.20 [sec]: New prediction is scheduled.
# Time 5.20 [sec]: New SAC control computation is scheduled.
# Time 5.20 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.22 [sec]: New prediction is available to the controller.
# Time 5.22 [sec]: New SAC control is available to the controller.
# Time 5.22 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.24 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.26 [sec]: Control: [-2.0220839977264404, -3.4512572288513184] is applied to the system.
# Time 5.28 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.30 [sec]: New SAC control computation is scheduled.
# Time 5.30 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.32 [sec]: New SAC control is available to the controller.
# Time 5.32 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.34 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.36 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.38 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.40 [sec]: New SAC control computation is scheduled.
# Time 5.40 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.42 [sec]: New SAC control is available to the controller.
# Time 5.42 [sec]: Control: [-2.6073503494262695, -4.266347885131836] is applied to the system.
# Time 5.44 [sec]: Control: [-2.6073503494262695, -4.266347885131836] is applied to the system.
# Time 5.46 [sec]: Control: [2.4200663566589355, 4.375303268432617] is applied to the system.
# Time 5.48 [sec]: Control: [2.4200663566589355, 4.375303268432617] is applied to the system.
# Time 5.50 [sec]: New SAC control computation is scheduled.
# Time 5.50 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.52 [sec]: New SAC control is available to the controller.
# Time 5.52 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.54 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.56 [sec]: Control: [-0.12824714183807373, 0.3165498375892639] is applied to the system.
# Time 5.58 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.60 [sec]: New measurement is obtained.
# Time 5.60 [sec]: New prediction is scheduled.
# Time 5.60 [sec]: New SAC control computation is scheduled.
# Time 5.60 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.62 [sec]: New prediction is available to the controller.
# Time 5.62 [sec]: New SAC control is available to the controller.
# Time 5.62 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.64 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.66 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.68 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.70 [sec]: New SAC control computation is scheduled.
# Time 5.70 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.72 [sec]: New SAC control is available to the controller.
# Time 5.72 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.74 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.76 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.78 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.80 [sec]: New SAC control computation is scheduled.
# Time 5.80 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.82 [sec]: New SAC control is available to the controller.
# Time 5.82 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.84 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.86 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.88 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.90 [sec]: New SAC control computation is scheduled.
# Time 5.90 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.92 [sec]: New SAC control is available to the controller.
# Time 5.92 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.94 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.96 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.98 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 6.00 [sec]: New measurement is obtained.
# Time 6.00 [sec]: New prediction is scheduled.
# Time 6.00 [sec]: New SAC control computation is scheduled.
# Time 6.00 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 6.02 [sec]: New prediction is available to the controller.
# Time 6.02 [sec]: New SAC control is available to the controller.
# Time 6.02 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 6.04 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 6.06 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 6.08 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 6.10 [sec]: New SAC control computation is scheduled.
# Time 6.10 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 6.12 [sec]: New SAC control is available to the controller.
# Time 6.12 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 6.14 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 6.16 [sec]: Control: [-1.2111142873764038, -4.85110330581665] is applied to the system.
# Time 6.18 [sec]: Control: [3.3166072368621826, 3.741672992706299] is applied to the system.
# Time 6.20 [sec]: New SAC control computation is scheduled.
# Time 6.20 [sec]: Control: [0.0, 2.0] is applied to the system.
# Time 6.22 [sec]: New SAC control is available to the controller.
# Time 6.22 [sec]: Control: [0.0, 2.0] is applied to the system.
# Time 6.24 [sec]: Control: [0.0, 2.0] is applied to the system.
# Time 6.26 [sec]: Control: [0.0, 2.0] is applied to the system.
# Time 6.28 [sec]: Control: [0.0, 2.0] is applied to the system.
# Time 6.30 [sec]: New SAC control computation is scheduled.
# Time 6.30 [sec]: Control: [0.0, 2.0] is applied to the system.
# Time 6.32 [sec]: New SAC control is available to the controller.
# Time 6.32 [sec]: Control: [0.0, 2.0] is applied to the system.
# Time 6.34 [sec]: Control: [0.0, 2.0] is applied to the system.
# Time 6.36 [sec]: Control: [3.999600410461426, -0.05653141438961029] is applied to the system.
# Time 6.38 [sec]: Control: [0.0, 2.0] is applied to the system.
# Time 6.40 [sec]: New measurement is obtained.
# Time 6.40 [sec]: New prediction is scheduled.
# Time 6.40 [sec]: New SAC control computation is scheduled.
# Time 6.40 [sec]: Control: [0.0, 2.0] is applied to the system.
# Time 6.42 [sec]: New prediction is available to the controller.
# Time 6.42 [sec]: New SAC control is available to the controller.
# Time 6.42 [sec]: Control: [0.0, 2.0] is applied to the system.
# Time 6.44 [sec]: Control: [0.0, 2.0] is applied to the system.
# Time 6.46 [sec]: Control: [0.0, 2.0] is applied to the system.
# Time 6.48 [sec]: Control: [0.0, 2.0] is applied to the system.
# Time 6.50 [sec]: New SAC control computation is scheduled.
# Time 6.50 [sec]: Control: [0.0, 2.0] is applied to the system.
# Time 6.52 [sec]: New SAC control is available to the controller.
# Time 6.52 [sec]: Control: [0.0, 2.0] is applied to the system.
# Time 6.54 [sec]: Control: [0.0, 2.0] is applied to the system.
# Time 6.56 [sec]: Control: [-2.255509853363037, -4.462362289428711] is applied to the system.
# Time 6.58 [sec]: Control: [-2.255509853363037, -4.462362289428711] is applied to the system.
# Time 6.60 [sec]: New SAC control computation is scheduled.
# Time 6.60 [sec]: Control: [0.0, 2.0] is applied to the system.
# Time 6.62 [sec]: New SAC control is available to the controller.
# Time 6.62 [sec]: Control: [0.0, 2.0] is applied to the system.
# Time 6.64 [sec]: Control: [0.0, 2.0] is applied to the system.
# Time 6.66 [sec]: Control: [1.5742840766906738, -4.745696067810059] is applied to the system.
# Time 6.68 [sec]: Control: [0.0, 2.0] is applied to the system.
# Time 6.70 [sec]: New SAC control computation is scheduled.
# Time 6.70 [sec]: Control: [0.0, 2.0] is applied to the system.
# Time 6.72 [sec]: New SAC control is available to the controller.
# Time 6.72 [sec]: Control: [0.0, 2.0] is applied to the system.
# Time 6.74 [sec]: Control: [4.992584705352783, -0.2722078561782837] is applied to the system.
# Time 6.76 [sec]: Control: [4.992584705352783, -0.2722078561782837] is applied to the system.
# Time 6.78 [sec]: Control: [0.0, 2.0] is applied to the system.
# Time 6.80 [sec]: New measurement is obtained.
# Time 6.80 [sec]: New prediction is scheduled.
# Time 6.80 [sec]: New SAC control computation is scheduled.
# Time 6.80 [sec]: Control: [0.0, 2.0] is applied to the system.
# Time 6.82 [sec]: New prediction is available to the controller.
# Time 6.82 [sec]: New SAC control is available to the controller.
# Time 6.82 [sec]: Control: [0.0, 2.0] is applied to the system.
# Time 6.84 [sec]: Control: [0.0, 2.0] is applied to the system.
# Time 6.86 [sec]: Control: [0.0, 2.0] is applied to the system.
# Time 6.88 [sec]: Control: [0.0, 2.0] is applied to the system.
# Time 6.90 [sec]: New SAC control computation is scheduled.
# Time 6.90 [sec]: Control: [0.0, 2.0] is applied to the system.
# Time 6.92 [sec]: New SAC control is available to the controller.
# Time 6.92 [sec]: Control: [0.0, 2.0] is applied to the system.
# Time 6.94 [sec]: Control: [0.0, 2.0] is applied to the system.
# Time 6.96 [sec]: Control: [-2.3179337978363037, -4.430257797241211] is applied to the system.
# Time 6.98 [sec]: Control: [0.4258691072463989, 1.9541329145431519] is applied to the system.
# Time 7.00 [sec]: New SAC control computation is scheduled.
# Time 7.00 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 7.02 [sec]: New SAC control is available to the controller.
# Time 7.02 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 7.04 [sec]: Control: [1.5950558185577393, 4.738754749298096] is applied to the system.
# Time 7.06 [sec]: Control: [1.5950558185577393, 4.738754749298096] is applied to the system.
# Time 7.08 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 7.10 [sec]: New SAC control computation is scheduled.
# Time 7.10 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 7.12 [sec]: New SAC control is available to the controller.
# Time 7.12 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 7.14 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 7.16 [sec]: Control: [-0.9572921991348267, -1.7560158967971802] is applied to the system.
# Time 7.18 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 7.20 [sec]: New measurement is obtained.
# Time 7.20 [sec]: New prediction is scheduled.
# Time 7.20 [sec]: New SAC control computation is scheduled.
# Time 7.20 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 7.22 [sec]: New prediction is available to the controller.
# Time 7.22 [sec]: New SAC control is available to the controller.
# Time 7.22 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 7.24 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 7.26 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 7.28 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 7.30 [sec]: New SAC control computation is scheduled.
# Time 7.30 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 7.32 [sec]: New SAC control is available to the controller.
# Time 7.32 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 7.34 [sec]: Control: [-2.3780133724212646, -4.398301124572754] is applied to the system.
# Time 7.36 [sec]: Control: [-2.3780133724212646, -4.398301124572754] is applied to the system.
# Time 7.38 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 7.40 [sec]: New SAC control computation is scheduled.
# Time 7.40 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 7.42 [sec]: New SAC control is available to the controller.
# Time 7.42 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 7.44 [sec]: Control: [2.30427885055542, 4.437375068664551] is applied to the system.
# Time 7.46 [sec]: Control: [2.30427885055542, 4.437375068664551] is applied to the system.
# Time 7.48 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 7.50 [sec]: New SAC control computation is scheduled.
# Time 7.50 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 7.52 [sec]: New SAC control is available to the controller.
# Time 7.52 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 7.54 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 7.56 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 7.58 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 7.60 [sec]: New measurement is obtained.
# Time 7.60 [sec]: New prediction is scheduled.
# Time 7.60 [sec]: New SAC control computation is scheduled.
# Time 7.60 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 7.62 [sec]: New prediction is available to the controller.
# Time 7.62 [sec]: New SAC control is available to the controller.
# Time 7.62 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 7.64 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 7.66 [sec]: Control: [-0.15380312502384186, -0.6001783013343811] is applied to the system.
# Time 7.68 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 7.70 [sec]: New SAC control computation is scheduled.
# Time 7.70 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 7.72 [sec]: New SAC control is available to the controller.
# Time 7.72 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 7.74 [sec]: Control: [-2.3466858863830566, -4.415095329284668] is applied to the system.
# Time 7.76 [sec]: Control: [-2.3466858863830566, -4.415095329284668] is applied to the system.
# Time 7.78 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 7.80 [sec]: New SAC control computation is scheduled.
# Time 7.80 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 7.82 [sec]: New SAC control is available to the controller.
# Time 7.82 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 7.84 [sec]: Control: [2.5928597450256348, 4.275169849395752] is applied to the system.
# Time 7.86 [sec]: Control: [2.5928597450256348, 4.275169849395752] is applied to the system.
# Time 7.88 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 7.90 [sec]: New SAC control computation is scheduled.
# Time 7.90 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 7.92 [sec]: New SAC control is available to the controller.
# Time 7.92 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 7.94 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 7.96 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 7.98 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.00 [sec]: New measurement is obtained.
# Time 8.00 [sec]: New prediction is scheduled.
# Time 8.00 [sec]: New SAC control computation is scheduled.
# Time 8.00 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.02 [sec]: New prediction is available to the controller.
# Time 8.02 [sec]: New SAC control is available to the controller.
# Time 8.02 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.04 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.06 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.08 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.10 [sec]: New SAC control computation is scheduled.
# Time 8.10 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.12 [sec]: New SAC control is available to the controller.
# Time 8.12 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.14 [sec]: Control: [-2.3462026119232178, -4.415351867675781] is applied to the system.
# Time 8.16 [sec]: Control: [-2.3462026119232178, -4.415351867675781] is applied to the system.
# Time 8.18 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.20 [sec]: New SAC control computation is scheduled.
# Time 8.20 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.22 [sec]: New SAC control is available to the controller.
# Time 8.22 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.24 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.26 [sec]: Control: [2.6750710010528564, 4.224215507507324] is applied to the system.
# Time 8.28 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.30 [sec]: New SAC control computation is scheduled.
# Time 8.30 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.32 [sec]: New SAC control is available to the controller.
# Time 8.32 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.34 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.36 [sec]: Control: [1.2576407194137573, 1.5551011562347412] is applied to the system.
# Time 8.38 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.40 [sec]: New measurement is obtained.
# Time 8.40 [sec]: New prediction is scheduled.
# Time 8.40 [sec]: New SAC control computation is scheduled.
# Time 8.40 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.42 [sec]: New prediction is available to the controller.
# Time 8.42 [sec]: New SAC control is available to the controller.
# Time 8.42 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.44 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.46 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.48 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.50 [sec]: New SAC control computation is scheduled.
# Time 8.50 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.52 [sec]: New SAC control is available to the controller.
# Time 8.52 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.54 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.56 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.58 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.60 [sec]: New SAC control computation is scheduled.
# Time 8.60 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.62 [sec]: New SAC control is available to the controller.
# Time 8.62 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.64 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.66 [sec]: Control: [-2.5247256755828857, -4.3157572746276855] is applied to the system.
# Time 8.68 [sec]: Control: [4.0087409019470215, 2.988309860229492] is applied to the system.
# Time 8.70 [sec]: New SAC control computation is scheduled.
# Time 8.70 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.72 [sec]: New SAC control is available to the controller.
# Time 8.72 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.74 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.76 [sec]: Control: [0.7470750212669373, 1.1041054725646973] is applied to the system.
# Time 8.78 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.80 [sec]: New measurement is obtained.
# Time 8.80 [sec]: New prediction is scheduled.
# Time 8.80 [sec]: New SAC control computation is scheduled.
# Time 8.80 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.82 [sec]: New prediction is available to the controller.
# Time 8.82 [sec]: New SAC control is available to the controller.
# Time 8.82 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.84 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.86 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.88 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.90 [sec]: New SAC control computation is scheduled.
# Time 8.90 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.92 [sec]: New SAC control is available to the controller.
# Time 8.92 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.94 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.96 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.98 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.00 [sec]: New SAC control computation is scheduled.
# Time 9.00 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.02 [sec]: New SAC control is available to the controller.
# Time 9.02 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.04 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.06 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.08 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.10 [sec]: New SAC control computation is scheduled.
# Time 9.10 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.12 [sec]: New SAC control is available to the controller.
# Time 9.12 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.14 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.16 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.18 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.20 [sec]: New measurement is obtained.
# Time 9.20 [sec]: New prediction is scheduled.
# Time 9.20 [sec]: New SAC control computation is scheduled.
# Time 9.20 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.22 [sec]: New prediction is available to the controller.
# Time 9.22 [sec]: New SAC control is available to the controller.
# Time 9.22 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.24 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.26 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.28 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.30 [sec]: New SAC control computation is scheduled.
# Time 9.30 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.32 [sec]: New SAC control is available to the controller.
# Time 9.32 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.34 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.36 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.38 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.40 [sec]: New SAC control computation is scheduled.
# Time 9.40 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.42 [sec]: New SAC control is available to the controller.
# Time 9.42 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.44 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.46 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.48 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.50 [sec]: New SAC control computation is scheduled.
# Time 9.50 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.52 [sec]: New SAC control is available to the controller.
# Time 9.52 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.54 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.56 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.58 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.60 [sec]: New measurement is obtained.
# Time 9.60 [sec]: New prediction is scheduled.
# Time 9.60 [sec]: New SAC control computation is scheduled.
# Time 9.60 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.62 [sec]: New prediction is available to the controller.
# Time 9.62 [sec]: New SAC control is available to the controller.
# Time 9.62 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.64 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.66 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.68 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.70 [sec]: New SAC control computation is scheduled.
# Time 9.70 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.72 [sec]: New SAC control is available to the controller.
# Time 9.72 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.74 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.76 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.78 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.80 [sec]: New SAC control computation is scheduled.
# Time 9.80 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.82 [sec]: New SAC control is available to the controller.
# Time 9.82 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.84 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.86 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.88 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.90 [sec]: New SAC control computation is scheduled.
# Time 9.90 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.92 [sec]: New SAC control is available to the controller.
# Time 9.92 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.94 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.96 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.98 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 10.00 [sec]: New measurement is obtained.

# %%
result.total_cnt_cost
# Out:
# 2.2691482492224018

# %%
result.total_pos_cost
# Out:
# 2.291065252249503

# %%
result.total_col_cost
# Out:
# 0.35775315657303386

# %%
result.total_cnt_cost + result.total_pos_cost + result.total_col_cost
# Out:
# 4.917966658044939

# %%
minimum([minimum(vcat([norm(get_position(w.e_state) - ap) for ap in values(w.ap_dict)], Inf))
                          for w in result.w_history])
# Out:
# 1.3951847909867754

# %%
make_gif(result, dtplot=0.02, fps=50, xlim=(-3. + -5.263534, 13. + -5.314636), 
         ylim=(0. + -5.263534, 10. + -5.314636), figsize=(600, 400),
         legendfontsize=7, legend=:bottomright, markersize=5., filename="4_data_oracle.gif",
         dummy_pos=controller.predictor.param.dummy_pos)
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:36
# ┌ Info: Saved animation to
# │   fn = /home/haruki/Documents/2020-21_Autumn/RiskSensitiveSAC.jl/notebook/4_data_oracle.gif
# └ @ Plots /home/haruki/.julia/packages/Plots/qZHsp/src/animation.jl:98
# Plots.AnimatedGif("/home/haruki/Documents/2020-21_Autumn/RiskSensitiveSAC.jl/notebook/4_data_oracle.gif")

# %%
save("4_data_oracle.jld2", "result", result)
