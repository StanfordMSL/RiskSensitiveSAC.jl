# %%
using Revise

ENV["PYCALL_JL_RUNTIME_PYTHON"] = Sys.which("python")
using FileIO
using JLD2
using RiskSensitiveSAC
# Out:
# ┌ Info: Number of Julia Thread(s): 1
# └ @ RiskSensitiveSAC /home/haruki/Documents/2020-21_Autumn/RiskSensitiveSAC.jl/src/RiskSensitiveSAC.jl:39
# ┌ Info: CUDA Device: GeForce RTX 2080 Ti
# └ @ RiskSensitiveSAC /home/haruki/Documents/2020-21_Autumn/RiskSensitiveSAC.jl/src/RiskSensitiveSAC.jl:40
# ┌ Info: Python executable used by PyCall: /home/haruki/Documents/2020-21_Autumn/RiskSensitiveSAC.jl/env_trajectron++/bin/python3.6
# └ @ RiskSensitiveSAC /home/haruki/Documents/2020-21_Autumn/RiskSensitiveSAC.jl/src/RiskSensitiveSAC.jl:41

# %%
include("$(@__DIR__)/../scripts/default_params/params_synthetic_gaussian.jl");

min_dist = 0.8;  # minimum separation distance required 

include("$(@__DIR__)/../scripts/parameter_setup_bic.jl");

# %%
scene_loader, controller, w_init, measurement_schedule, target_trajectory, target_speed, predictor =
controller_setup(scene_param,
                 cost_param=cost_param,
                 cnt_param=cnt_param,
                 dtc=dtc,
                 dto=dto,
                 prediction_steps=prediction_steps,
                 num_samples=num_samples,
                 sim_rng=sim_rng,
                 ado_pos_init_dict=ado_pos_init_dict,
                 ado_vel_dict=ado_vel_dict,
                 ego_pos_init_vec=ego_pos_init_vec,
                 ego_vel_init_vec=nothing,
                 ego_pos_goal_vec=ego_pos_goal_vec,
                 target_speed=target_speed,
                 sim_horizon=sim_horizon,
                 verbose=true);
# Out:
# Scene Mode: synthetic
# BIC Controller

# %%
result, ~, ~ = evaluate(scene_loader, controller, w_init, ego_pos_goal_vec, target_speed,
                  measurement_schedule, target_trajectory, pos_error_replan, predictor=predictor);
# Out:
# ┌ Warning: Time 0.00 [sec]: BIC computation took 22.461 [sec], which exceeds the maximum computation time allowed.
# └ @ RiskSensitiveSAC /home/haruki/Documents/2020-21_Autumn/RiskSensitiveSAC.jl/src/bic.jl:289
# ┌ Warning: Time 0.00 [sec]: This evaluation iteration took 0.29 [sec], which exceeds dtc.
# └ @ RiskSensitiveSAC /home/haruki/Documents/2020-21_Autumn/RiskSensitiveSAC.jl/src/evaluation.jl:249

# %%
display_log(result.log)
# Out:
# Time 0.00 [sec]: New BIC control computation is scheduled.
# Time 0.00 [sec]: New BIC control is available to the controller.
# Time 0.00 [sec]: Control: [-1.8424870935231452e-9, -3.739056464812443e-9] is applied to the system.
# Time 0.02 [sec]: Control: [-1.8424870935231452e-9, -3.739056464812443e-9] is applied to the system.
# Time 0.04 [sec]: Control: [-1.8424870935231452e-9, -3.739056464812443e-9] is applied to the system.
# Time 0.06 [sec]: Control: [-1.8424870935231452e-9, -3.739056464812443e-9] is applied to the system.
# Time 0.08 [sec]: Control: [-1.8424870935231452e-9, -3.739056464812443e-9] is applied to the system.
# Time 0.10 [sec]: New BIC control computation is scheduled.
# Time 0.10 [sec]: Control: [-1.8424870935231452e-9, -3.739056464812443e-9] is applied to the system.
# Time 0.12 [sec]: New BIC control is available to the controller.
# Time 0.12 [sec]: Control: [-0.1109968540625247, 8.360988331789992e-10] is applied to the system.
# Time 0.14 [sec]: Control: [-0.1109968540625247, 8.360988331789992e-10] is applied to the system.
# Time 0.16 [sec]: Control: [-0.1109968540625247, 8.360988331789992e-10] is applied to the system.
# Time 0.18 [sec]: Control: [-0.1109968540625247, 8.360988331789992e-10] is applied to the system.
# Time 0.20 [sec]: New BIC control computation is scheduled.
# Time 0.20 [sec]: Control: [-0.1109968540625247, 8.360988331789992e-10] is applied to the system.
# Time 0.22 [sec]: New BIC control is available to the controller.
# Time 0.22 [sec]: Control: [-0.2084748646982372, 1.8971484772679568e-10] is applied to the system.
# Time 0.24 [sec]: Control: [-0.2084748646982372, 1.8971484772679568e-10] is applied to the system.
# Time 0.26 [sec]: Control: [-0.2084748646982372, 1.8971484772679568e-10] is applied to the system.
# Time 0.28 [sec]: Control: [-0.2084748646982372, 1.8971484772679568e-10] is applied to the system.
# Time 0.30 [sec]: New BIC control computation is scheduled.
# Time 0.30 [sec]: Control: [-0.2084748646982372, 1.8971484772679568e-10] is applied to the system.
# Time 0.32 [sec]: New BIC control is available to the controller.
# Time 0.32 [sec]: Control: [-0.2895920015102969, 3.3521341602096965e-9] is applied to the system.
# Time 0.34 [sec]: Control: [-0.2895920015102969, 3.3521341602096965e-9] is applied to the system.
# Time 0.36 [sec]: Control: [-0.2895920015102969, 3.3521341602096965e-9] is applied to the system.
# Time 0.38 [sec]: Control: [-0.2895920015102969, 3.3521341602096965e-9] is applied to the system.
# Time 0.40 [sec]: New measurement is obtained.
# Time 0.40 [sec]: New BIC control computation is scheduled.
# Time 0.40 [sec]: Control: [-0.2895920015102969, 3.3521341602096965e-9] is applied to the system.
# Time 0.42 [sec]: New BIC control is available to the controller.
# Time 0.42 [sec]: Control: [0.08833181519842273, 3.004698357692546e-9] is applied to the system.
# Time 0.44 [sec]: Control: [0.08833181519842273, 3.004698357692546e-9] is applied to the system.
# Time 0.46 [sec]: Control: [0.08833181519842273, 3.004698357692546e-9] is applied to the system.
# Time 0.48 [sec]: Control: [0.08833181519842273, 3.004698357692546e-9] is applied to the system.
# Time 0.50 [sec]: New BIC control computation is scheduled.
# Time 0.50 [sec]: Control: [0.08833181519842273, 3.004698357692546e-9] is applied to the system.
# Time 0.52 [sec]: New BIC control is available to the controller.
# Time 0.52 [sec]: Control: [-0.01816671748101373, 2.4815513613358126e-9] is applied to the system.
# Time 0.54 [sec]: Control: [-0.01816671748101373, 2.4815513613358126e-9] is applied to the system.
# Time 0.56 [sec]: Control: [-0.01816671748101373, 2.4815513613358126e-9] is applied to the system.
# Time 0.58 [sec]: Control: [-0.01816671748101373, 2.4815513613358126e-9] is applied to the system.
# Time 0.60 [sec]: New BIC control computation is scheduled.
# Time 0.60 [sec]: Control: [-0.01816671748101373, 2.4815513613358126e-9] is applied to the system.
# Time 0.62 [sec]: New BIC control is available to the controller.
# Time 0.62 [sec]: Control: [-0.1237625497041746, 1.0976248267573023e-9] is applied to the system.
# Time 0.64 [sec]: Control: [-0.1237625497041746, 1.0976248267573023e-9] is applied to the system.
# Time 0.66 [sec]: Control: [-0.1237625497041746, 1.0976248267573023e-9] is applied to the system.
# Time 0.68 [sec]: Control: [-0.1237625497041746, 1.0976248267573023e-9] is applied to the system.
# Time 0.70 [sec]: New BIC control computation is scheduled.
# Time 0.70 [sec]: Control: [-0.1237625497041746, 1.0976248267573023e-9] is applied to the system.
# Time 0.72 [sec]: New BIC control is available to the controller.
# Time 0.72 [sec]: Control: [-0.21317115850834206, -1.0088536929167067e-9] is applied to the system.
# Time 0.74 [sec]: Control: [-0.21317115850834206, -1.0088536929167067e-9] is applied to the system.
# Time 0.76 [sec]: Control: [-0.21317115850834206, -1.0088536929167067e-9] is applied to the system.
# Time 0.78 [sec]: Control: [-0.21317115850834206, -1.0088536929167067e-9] is applied to the system.
# Time 0.80 [sec]: New measurement is obtained.
# Time 0.80 [sec]: New BIC control computation is scheduled.
# Time 0.80 [sec]: Control: [-0.21317115850834206, -1.0088536929167067e-9] is applied to the system.
# Time 0.82 [sec]: New BIC control is available to the controller.
# Time 0.82 [sec]: Control: [0.15676893708309567, 6.497270289545993e-10] is applied to the system.
# Time 0.84 [sec]: Control: [0.15676893708309567, 6.497270289545993e-10] is applied to the system.
# Time 0.86 [sec]: Control: [0.15676893708309567, 6.497270289545993e-10] is applied to the system.
# Time 0.88 [sec]: Control: [0.15676893708309567, 6.497270289545993e-10] is applied to the system.
# Time 0.90 [sec]: New BIC control computation is scheduled.
# Time 0.90 [sec]: Control: [0.15676893708309567, 6.497270289545993e-10] is applied to the system.
# Time 0.92 [sec]: New BIC control is available to the controller.
# Time 0.92 [sec]: Control: [0.0426540639033427, -1.9581254270133526e-9] is applied to the system.
# Time 0.94 [sec]: Control: [0.0426540639033427, -1.9581254270133526e-9] is applied to the system.
# Time 0.96 [sec]: Control: [0.0426540639033427, -1.9581254270133526e-9] is applied to the system.
# Time 0.98 [sec]: Control: [0.0426540639033427, -1.9581254270133526e-9] is applied to the system.
# Time 1.00 [sec]: New BIC control computation is scheduled.
# Time 1.00 [sec]: Control: [0.0426540639033427, -1.9581254270133526e-9] is applied to the system.
# Time 1.02 [sec]: New BIC control is available to the controller.
# Time 1.02 [sec]: Control: [-0.07015586675570858, 3.431409876973665e-10] is applied to the system.
# Time 1.04 [sec]: Control: [-0.07015586675570858, 3.431409876973665e-10] is applied to the system.
# Time 1.06 [sec]: Control: [-0.07015586675570858, 3.431409876973665e-10] is applied to the system.
# Time 1.08 [sec]: Control: [-0.07015586675570858, 3.431409876973665e-10] is applied to the system.
# Time 1.10 [sec]: New BIC control computation is scheduled.
# Time 1.10 [sec]: Control: [-0.07015586675570858, 3.431409876973665e-10] is applied to the system.
# Time 1.12 [sec]: New BIC control is available to the controller.
# Time 1.12 [sec]: Control: [-0.16635157656911145, 1.0492197989929936e-9] is applied to the system.
# Time 1.14 [sec]: Control: [-0.16635157656911145, 1.0492197989929936e-9] is applied to the system.
# Time 1.16 [sec]: Control: [-0.16635157656911145, 1.0492197989929936e-9] is applied to the system.
# Time 1.18 [sec]: Control: [-0.16635157656911145, 1.0492197989929936e-9] is applied to the system.
# Time 1.20 [sec]: New measurement is obtained.
# Time 1.20 [sec]: New BIC control computation is scheduled.
# Time 1.20 [sec]: Control: [-0.16635157656911145, 1.0492197989929936e-9] is applied to the system.
# Time 1.22 [sec]: New BIC control is available to the controller.
# Time 1.22 [sec]: Control: [0.19724465671701383, -1.2102963891102893e-8] is applied to the system.
# Time 1.24 [sec]: Control: [0.19724465671701383, -1.2102963891102893e-8] is applied to the system.
# Time 1.26 [sec]: Control: [0.19724465671701383, -1.2102963891102893e-8] is applied to the system.
# Time 1.28 [sec]: Control: [0.19724465671701383, -1.2102963891102893e-8] is applied to the system.
# Time 1.30 [sec]: New BIC control computation is scheduled.
# Time 1.30 [sec]: Control: [0.19724465671701383, -1.2102963891102893e-8] is applied to the system.
# Time 1.32 [sec]: New BIC control is available to the controller.
# Time 1.32 [sec]: Control: [0.07723807012943984, 4.393140907886631e-9] is applied to the system.
# Time 1.34 [sec]: Control: [0.07723807012943984, 4.393140907886631e-9] is applied to the system.
# Time 1.36 [sec]: Control: [0.07723807012943984, 4.393140907886631e-9] is applied to the system.
# Time 1.38 [sec]: Control: [0.07723807012943984, 4.393140907886631e-9] is applied to the system.
# Time 1.40 [sec]: New BIC control computation is scheduled.
# Time 1.40 [sec]: Control: [0.07723807012943984, 4.393140907886631e-9] is applied to the system.
# Time 1.42 [sec]: New BIC control is available to the controller.
# Time 1.42 [sec]: Control: [-0.041009163332003065, 4.5369911882999454e-10] is applied to the system.
# Time 1.44 [sec]: Control: [-0.041009163332003065, 4.5369911882999454e-10] is applied to the system.
# Time 1.46 [sec]: Control: [-0.041009163332003065, 4.5369911882999454e-10] is applied to the system.
# Time 1.48 [sec]: Control: [-0.041009163332003065, 4.5369911882999454e-10] is applied to the system.
# Time 1.50 [sec]: New BIC control computation is scheduled.
# Time 1.50 [sec]: Control: [-0.041009163332003065, 4.5369911882999454e-10] is applied to the system.
# Time 1.52 [sec]: New BIC control is available to the controller.
# Time 1.52 [sec]: Control: [-0.1421909629201215, 2.260972740273146e-9] is applied to the system.
# Time 1.54 [sec]: Control: [-0.1421909629201215, 2.260972740273146e-9] is applied to the system.
# Time 1.56 [sec]: Control: [-0.1421909629201215, 2.260972740273146e-9] is applied to the system.
# Time 1.58 [sec]: Control: [-0.1421909629201215, 2.260972740273146e-9] is applied to the system.
# Time 1.60 [sec]: New measurement is obtained.
# Time 1.60 [sec]: New BIC control computation is scheduled.
# Time 1.60 [sec]: Control: [-0.1421909629201215, 2.260972740273146e-9] is applied to the system.
# Time 1.62 [sec]: New BIC control is available to the controller.
# Time 1.62 [sec]: Control: [0.21686250095431364, -4.334956254868204e-9] is applied to the system.
# Time 1.64 [sec]: Control: [0.21686250095431364, -4.334956254868204e-9] is applied to the system.
# Time 1.66 [sec]: Control: [0.21686250095431364, -4.334956254868204e-9] is applied to the system.
# Time 1.68 [sec]: Control: [0.21686250095431364, -4.334956254868204e-9] is applied to the system.
# Time 1.70 [sec]: New BIC control computation is scheduled.
# Time 1.70 [sec]: Control: [0.21686250095431364, -4.334956254868204e-9] is applied to the system.
# Time 1.72 [sec]: New BIC control is available to the controller.
# Time 1.72 [sec]: Control: [0.09274448362001385, 4.1518987916253125e-10] is applied to the system.
# Time 1.74 [sec]: Control: [0.09274448362001385, 4.1518987916253125e-10] is applied to the system.
# Time 1.76 [sec]: Control: [0.09274448362001385, 4.1518987916253125e-10] is applied to the system.
# Time 1.78 [sec]: Control: [0.09274448362001385, 4.1518987916253125e-10] is applied to the system.
# Time 1.80 [sec]: New BIC control computation is scheduled.
# Time 1.80 [sec]: Control: [0.09274448362001385, 4.1518987916253125e-10] is applied to the system.
# Time 1.82 [sec]: New BIC control is available to the controller.
# Time 1.82 [sec]: Control: [-0.02919789633903062, 2.237981955145863e-8] is applied to the system.
# Time 1.84 [sec]: Control: [-0.02919789633903062, 2.237981955145863e-8] is applied to the system.
# Time 1.86 [sec]: Control: [-0.02919789633903062, 2.237981955145863e-8] is applied to the system.
# Time 1.88 [sec]: Control: [-0.02919789633903062, 2.237981955145863e-8] is applied to the system.
# Time 1.90 [sec]: New BIC control computation is scheduled.
# Time 1.90 [sec]: Control: [-0.02919789633903062, 2.237981955145863e-8] is applied to the system.
# Time 1.92 [sec]: New BIC control is available to the controller.
# Time 1.92 [sec]: Control: [-0.1336762373470331, 7.443455081259218e-9] is applied to the system.
# Time 1.94 [sec]: Control: [-0.1336762373470331, 7.443455081259218e-9] is applied to the system.
# Time 1.96 [sec]: Control: [-0.1336762373470331, 7.443455081259218e-9] is applied to the system.
# Time 1.98 [sec]: Control: [-0.1336762373470331, 7.443455081259218e-9] is applied to the system.
# Time 2.00 [sec]: New measurement is obtained.
# Time 2.00 [sec]: New BIC control computation is scheduled.
# Time 2.00 [sec]: Control: [-0.1336762373470331, 7.443455081259218e-9] is applied to the system.
# Time 2.02 [sec]: New BIC control is available to the controller.
# Time 2.02 [sec]: Control: [0.2224594653123538, -5.746135511142709e-9] is applied to the system.
# Time 2.04 [sec]: Control: [0.2224594653123538, -5.746135511142709e-9] is applied to the system.
# Time 2.06 [sec]: Control: [0.2224594653123538, -5.746135511142709e-9] is applied to the system.
# Time 2.08 [sec]: Control: [0.2224594653123538, -5.746135511142709e-9] is applied to the system.
# Time 2.10 [sec]: New BIC control computation is scheduled.
# Time 2.10 [sec]: Control: [0.2224594653123538, -5.746135511142709e-9] is applied to the system.
# Time 2.12 [sec]: New BIC control is available to the controller.
# Time 2.12 [sec]: Control: [0.09578114911081749, -1.574702673508911e-7] is applied to the system.
# Time 2.14 [sec]: Control: [0.09578114911081749, -1.574702673508911e-7] is applied to the system.
# Time 2.16 [sec]: Control: [0.09578114911081749, -1.574702673508911e-7] is applied to the system.
# Time 2.18 [sec]: Control: [0.09578114911081749, -1.574702673508911e-7] is applied to the system.
# Time 2.20 [sec]: New BIC control computation is scheduled.
# Time 2.20 [sec]: Control: [0.09578114911081749, -1.574702673508911e-7] is applied to the system.
# Time 2.22 [sec]: New BIC control is available to the controller.
# Time 2.22 [sec]: Control: [-0.028385960476408033, 1.6576733253206177e-8] is applied to the system.
# Time 2.24 [sec]: Control: [-0.028385960476408033, 1.6576733253206177e-8] is applied to the system.
# Time 2.26 [sec]: Control: [-0.028385960476408033, 1.6576733253206177e-8] is applied to the system.
# Time 2.28 [sec]: Control: [-0.028385960476408033, 1.6576733253206177e-8] is applied to the system.
# Time 2.30 [sec]: New BIC control computation is scheduled.
# Time 2.30 [sec]: Control: [-0.028385960476408033, 1.6576733253206177e-8] is applied to the system.
# Time 2.32 [sec]: New BIC control is available to the controller.
# Time 2.32 [sec]: Control: [-0.13477685907375425, 6.960897639580754e-8] is applied to the system.
# Time 2.34 [sec]: Control: [-0.13477685907375425, 6.960897639580754e-8] is applied to the system.
# Time 2.36 [sec]: Control: [-0.13477685907375425, 6.960897639580754e-8] is applied to the system.
# Time 2.38 [sec]: Control: [-0.13477685907375425, 6.960897639580754e-8] is applied to the system.
# Time 2.40 [sec]: New measurement is obtained.
# Time 2.40 [sec]: New BIC control computation is scheduled.
# Time 2.40 [sec]: Control: [-0.13477685907375425, 6.960897639580754e-8] is applied to the system.
# Time 2.42 [sec]: New BIC control is available to the controller.
# Time 2.42 [sec]: Control: [0.21973557570942037, 1.2257926832470887e-8] is applied to the system.
# Time 2.44 [sec]: Control: [0.21973557570942037, 1.2257926832470887e-8] is applied to the system.
# Time 2.46 [sec]: Control: [0.21973557570942037, 1.2257926832470887e-8] is applied to the system.
# Time 2.48 [sec]: Control: [0.21973557570942037, 1.2257926832470887e-8] is applied to the system.
# Time 2.50 [sec]: New BIC control computation is scheduled.
# Time 2.50 [sec]: Control: [0.21973557570942037, 1.2257926832470887e-8] is applied to the system.
# Time 2.52 [sec]: New BIC control is available to the controller.
# Time 2.52 [sec]: Control: [0.09170011264615414, 8.845268787011217e-9] is applied to the system.
# Time 2.54 [sec]: Control: [0.09170011264615414, 8.845268787011217e-9] is applied to the system.
# Time 2.56 [sec]: Control: [0.09170011264615414, 8.845268787011217e-9] is applied to the system.
# Time 2.58 [sec]: Control: [0.09170011264615414, 8.845268787011217e-9] is applied to the system.
# Time 2.60 [sec]: New BIC control computation is scheduled.
# Time 2.60 [sec]: Control: [0.09170011264615414, 8.845268787011217e-9] is applied to the system.
# Time 2.62 [sec]: New BIC control is available to the controller.
# Time 2.62 [sec]: Control: [-0.0335812343696948, 1.4437590578194044e-9] is applied to the system.
# Time 2.64 [sec]: Control: [-0.0335812343696948, 1.4437590578194044e-9] is applied to the system.
# Time 2.66 [sec]: Control: [-0.0335812343696948, 1.4437590578194044e-9] is applied to the system.
# Time 2.68 [sec]: Control: [-0.0335812343696948, 1.4437590578194044e-9] is applied to the system.
# Time 2.70 [sec]: New BIC control computation is scheduled.
# Time 2.70 [sec]: Control: [-0.0335812343696948, 1.4437590578194044e-9] is applied to the system.
# Time 2.72 [sec]: New BIC control is available to the controller.
# Time 2.72 [sec]: Control: [-0.14086539061834225, 8.29841612694465e-9] is applied to the system.
# Time 2.74 [sec]: Control: [-0.14086539061834225, 8.29841612694465e-9] is applied to the system.
# Time 2.76 [sec]: Control: [-0.14086539061834225, 8.29841612694465e-9] is applied to the system.
# Time 2.78 [sec]: Control: [-0.14086539061834225, 8.29841612694465e-9] is applied to the system.
# Time 2.80 [sec]: New measurement is obtained.
# Time 2.80 [sec]: New BIC control computation is scheduled.
# Time 2.80 [sec]: Control: [-0.14086539061834225, 8.29841612694465e-9] is applied to the system.
# Time 2.82 [sec]: New BIC control is available to the controller.
# Time 2.82 [sec]: Control: [0.21295287121731288, 5.845271269139503e-9] is applied to the system.
# Time 2.84 [sec]: Control: [0.21295287121731288, 5.845271269139503e-9] is applied to the system.
# Time 2.86 [sec]: Control: [0.21295287121731288, 5.845271269139503e-9] is applied to the system.
# Time 2.88 [sec]: Control: [0.21295287121731288, 5.845271269139503e-9] is applied to the system.
# Time 2.90 [sec]: New BIC control computation is scheduled.
# Time 2.90 [sec]: Control: [0.21295287121731288, 5.845271269139503e-9] is applied to the system.
# Time 2.92 [sec]: New BIC control is available to the controller.
# Time 2.92 [sec]: Control: [0.08440071572169264, -1.246533527346267e-6] is applied to the system.
# Time 2.94 [sec]: Control: [0.08440071572169264, -1.246533527346267e-6] is applied to the system.
# Time 2.96 [sec]: Control: [0.08440071572169264, -1.246533527346267e-6] is applied to the system.
# Time 2.98 [sec]: Control: [0.08440071572169264, -1.246533527346267e-6] is applied to the system.
# Time 3.00 [sec]: New BIC control computation is scheduled.
# Time 3.00 [sec]: Control: [0.08440071572169264, -1.246533527346267e-6] is applied to the system.
# Time 3.02 [sec]: New BIC control is available to the controller.
# Time 3.02 [sec]: Control: [-0.041236967828883725, 1.5851682486294683e-7] is applied to the system.
# Time 3.04 [sec]: Control: [-0.041236967828883725, 1.5851682486294683e-7] is applied to the system.
# Time 3.06 [sec]: Control: [-0.041236967828883725, 1.5851682486294683e-7] is applied to the system.
# Time 3.08 [sec]: Control: [-0.041236967828883725, 1.5851682486294683e-7] is applied to the system.
# Time 3.10 [sec]: New BIC control computation is scheduled.
# Time 3.10 [sec]: Control: [-0.041236967828883725, 1.5851682486294683e-7] is applied to the system.
# Time 3.12 [sec]: New BIC control is available to the controller.
# Time 3.12 [sec]: Control: [-0.14873960789260876, 1.601638104753898e-6] is applied to the system.
# Time 3.14 [sec]: Control: [-0.14873960789260876, 1.601638104753898e-6] is applied to the system.
# Time 3.16 [sec]: Control: [-0.14873960789260876, 1.601638104753898e-6] is applied to the system.
# Time 3.18 [sec]: Control: [-0.14873960789260876, 1.601638104753898e-6] is applied to the system.
# Time 3.20 [sec]: New measurement is obtained.
# Time 3.20 [sec]: New BIC control computation is scheduled.
# Time 3.20 [sec]: Control: [-0.14873960789260876, 1.601638104753898e-6] is applied to the system.
# Time 3.22 [sec]: New BIC control is available to the controller.
# Time 3.22 [sec]: Control: [0.20498387991392147, -1.906526325752383e-9] is applied to the system.
# Time 3.24 [sec]: Control: [0.20498387991392147, -1.906526325752383e-9] is applied to the system.
# Time 3.26 [sec]: Control: [0.20498387991392147, -1.906526325752383e-9] is applied to the system.
# Time 3.28 [sec]: Control: [0.20498387991392147, -1.906526325752383e-9] is applied to the system.
# Time 3.30 [sec]: New BIC control computation is scheduled.
# Time 3.30 [sec]: Control: [0.20498387991392147, -1.906526325752383e-9] is applied to the system.
# Time 3.32 [sec]: New BIC control is available to the controller.
# Time 3.32 [sec]: Control: [0.07644236583982927, -4.937091722444472e-8] is applied to the system.
# Time 3.34 [sec]: Control: [0.07644236583982927, -4.937091722444472e-8] is applied to the system.
# Time 3.36 [sec]: Control: [0.07644236583982927, -4.937091722444472e-8] is applied to the system.
# Time 3.38 [sec]: Control: [0.07644236583982927, -4.937091722444472e-8] is applied to the system.
# Time 3.40 [sec]: New BIC control computation is scheduled.
# Time 3.40 [sec]: Control: [0.07644236583982927, -4.937091722444472e-8] is applied to the system.
# Time 3.42 [sec]: New BIC control is available to the controller.
# Time 3.42 [sec]: Control: [-0.04909651854054517, -4.9656259071311497e-8] is applied to the system.
# Time 3.44 [sec]: Control: [-0.04909651854054517, -4.9656259071311497e-8] is applied to the system.
# Time 3.46 [sec]: Control: [-0.04909651854054517, -4.9656259071311497e-8] is applied to the system.
# Time 3.48 [sec]: Control: [-0.04909651854054517, -4.9656259071311497e-8] is applied to the system.
# Time 3.50 [sec]: New BIC control computation is scheduled.
# Time 3.50 [sec]: Control: [-0.04909651854054517, -4.9656259071311497e-8] is applied to the system.
# Time 3.52 [sec]: New BIC control is available to the controller.
# Time 3.52 [sec]: Control: [-0.15642279300654618, -3.380782656403452e-7] is applied to the system.
# Time 3.54 [sec]: Control: [-0.15642279300654618, -3.380782656403452e-7] is applied to the system.
# Time 3.56 [sec]: Control: [-0.15642279300654618, -3.380782656403452e-7] is applied to the system.
# Time 3.58 [sec]: Control: [-0.15642279300654618, -3.380782656403452e-7] is applied to the system.
# Time 3.60 [sec]: New measurement is obtained.
# Time 3.60 [sec]: New BIC control computation is scheduled.
# Time 3.60 [sec]: Control: [-0.15642279300654618, -3.380782656403452e-7] is applied to the system.
# Time 3.62 [sec]: New BIC control is available to the controller.
# Time 3.62 [sec]: Control: [0.19753855537038312, -9.350040292578194e-9] is applied to the system.
# Time 3.64 [sec]: Control: [0.19753855537038312, -9.350040292578194e-9] is applied to the system.
# Time 3.66 [sec]: Control: [0.19753855537038312, -9.350040292578194e-9] is applied to the system.
# Time 3.68 [sec]: Control: [0.19753855537038312, -9.350040292578194e-9] is applied to the system.
# Time 3.70 [sec]: New BIC control computation is scheduled.
# Time 3.70 [sec]: Control: [0.19753855537038312, -9.350040292578194e-9] is applied to the system.
# Time 3.72 [sec]: New BIC control is available to the controller.
# Time 3.72 [sec]: Control: [0.06928016340570821, 2.83945929943063e-5] is applied to the system.
# Time 3.74 [sec]: Control: [0.06928016340570821, 2.83945929943063e-5] is applied to the system.
# Time 3.76 [sec]: Control: [0.06928016340570821, 2.83945929943063e-5] is applied to the system.
# Time 3.78 [sec]: Control: [0.06928016340570821, 2.83945929943063e-5] is applied to the system.
# Time 3.80 [sec]: New BIC control computation is scheduled.
# Time 3.80 [sec]: Control: [0.06928016340570821, 2.83945929943063e-5] is applied to the system.
# Time 3.82 [sec]: New BIC control is available to the controller.
# Time 3.82 [sec]: Control: [-0.055921317098073055, -3.458138410559248e-6] is applied to the system.
# Time 3.84 [sec]: Control: [-0.055921317098073055, -3.458138410559248e-6] is applied to the system.
# Time 3.86 [sec]: Control: [-0.055921317098073055, -3.458138410559248e-6] is applied to the system.
# Time 3.88 [sec]: Control: [-0.055921317098073055, -3.458138410559248e-6] is applied to the system.
# Time 3.90 [sec]: New BIC control computation is scheduled.
# Time 3.90 [sec]: Control: [-0.055921317098073055, -3.458138410559248e-6] is applied to the system.
# Time 3.92 [sec]: New BIC control is available to the controller.
# Time 3.92 [sec]: Control: [-0.16288674412712265, -3.975229493110616e-6] is applied to the system.
# Time 3.94 [sec]: Control: [-0.16288674412712265, -3.975229493110616e-6] is applied to the system.
# Time 3.96 [sec]: Control: [-0.16288674412712265, -3.975229493110616e-6] is applied to the system.
# Time 3.98 [sec]: Control: [-0.16288674412712265, -3.975229493110616e-6] is applied to the system.
# Time 4.00 [sec]: New measurement is obtained.
# Time 4.00 [sec]: New BIC control computation is scheduled.
# Time 4.00 [sec]: Control: [-0.16288674412712265, -3.975229493110616e-6] is applied to the system.
# Time 4.02 [sec]: New BIC control is available to the controller.
# Time 4.02 [sec]: Control: [0.19145756052008925, -3.877539034191141e-6] is applied to the system.
# Time 4.04 [sec]: Control: [0.19145756052008925, -3.877539034191141e-6] is applied to the system.
# Time 4.06 [sec]: Control: [0.19145756052008925, -3.877539034191141e-6] is applied to the system.
# Time 4.08 [sec]: Control: [0.19145756052008925, -3.877539034191141e-6] is applied to the system.
# Time 4.10 [sec]: New BIC control computation is scheduled.
# Time 4.10 [sec]: Control: [0.19145756052008925, -3.877539034191141e-6] is applied to the system.
# Time 4.12 [sec]: New BIC control is available to the controller.
# Time 4.12 [sec]: Control: [0.06360309858060419, -3.5188008886204583e-6] is applied to the system.
# Time 4.14 [sec]: Control: [0.06360309858060419, -3.5188008886204583e-6] is applied to the system.
# Time 4.16 [sec]: Control: [0.06360309858060419, -3.5188008886204583e-6] is applied to the system.
# Time 4.18 [sec]: Control: [0.06360309858060419, -3.5188008886204583e-6] is applied to the system.
# Time 4.20 [sec]: New BIC control computation is scheduled.
# Time 4.20 [sec]: Control: [0.06360309858060419, -3.5188008886204583e-6] is applied to the system.
# Time 4.22 [sec]: New BIC control is available to the controller.
# Time 4.22 [sec]: Control: [-0.224210795575974, 0.16912004437466138] is applied to the system.
# Time 4.24 [sec]: Control: [-0.224210795575974, 0.16912004437466138] is applied to the system.
# Time 4.26 [sec]: Control: [-0.224210795575974, 0.16912004437466138] is applied to the system.
# Time 4.28 [sec]: Control: [-0.224210795575974, 0.16912004437466138] is applied to the system.
# Time 4.30 [sec]: New BIC control computation is scheduled.
# Time 4.30 [sec]: Control: [-0.224210795575974, 0.16912004437466138] is applied to the system.
# Time 4.32 [sec]: New BIC control is available to the controller.
# Time 4.32 [sec]: Control: [-0.39949074322729067, 0.2595154553593607] is applied to the system.
# Time 4.34 [sec]: Control: [-0.39949074322729067, 0.2595154553593607] is applied to the system.
# Time 4.36 [sec]: Control: [-0.39949074322729067, 0.2595154553593607] is applied to the system.
# Time 4.38 [sec]: Control: [-0.39949074322729067, 0.2595154553593607] is applied to the system.
# Time 4.40 [sec]: New measurement is obtained.
# Time 4.40 [sec]: New BIC control computation is scheduled.
# Time 4.40 [sec]: Control: [-0.39949074322729067, 0.2595154553593607] is applied to the system.
# Time 4.42 [sec]: New BIC control is available to the controller.
# Time 4.42 [sec]: Control: [-3.2717749342019187, 2.440041523928681] is applied to the system.
# Time 4.44 [sec]: Control: [-3.2717749342019187, 2.440041523928681] is applied to the system.
# Time 4.46 [sec]: Control: [-3.2717749342019187, 2.440041523928681] is applied to the system.
# Time 4.48 [sec]: Control: [-3.2717749342019187, 2.440041523928681] is applied to the system.
# Time 4.50 [sec]: New BIC control computation is scheduled.
# Time 4.50 [sec]: Control: [-3.2717749342019187, 2.440041523928681] is applied to the system.
# Time 4.52 [sec]: New BIC control is available to the controller.
# Time 4.52 [sec]: Control: [-2.0181264403192376, 1.691783968416685] is applied to the system.
# Time 4.54 [sec]: Control: [-2.0181264403192376, 1.691783968416685] is applied to the system.
# Time 4.56 [sec]: Control: [-2.0181264403192376, 1.691783968416685] is applied to the system.
# Time 4.58 [sec]: Control: [-2.0181264403192376, 1.691783968416685] is applied to the system.
# Time 4.60 [sec]: New BIC control computation is scheduled.
# Time 4.60 [sec]: Control: [-2.0181264403192376, 1.691783968416685] is applied to the system.
# Time 4.62 [sec]: New BIC control is available to the controller.
# Time 4.62 [sec]: Control: [-0.778600022505284, 0.7977771903843505] is applied to the system.
# Time 4.64 [sec]: Control: [-0.778600022505284, 0.7977771903843505] is applied to the system.
# Time 4.66 [sec]: Control: [-0.778600022505284, 0.7977771903843505] is applied to the system.
# Time 4.68 [sec]: Control: [-0.778600022505284, 0.7977771903843505] is applied to the system.
# Time 4.70 [sec]: New BIC control computation is scheduled.
# Time 4.70 [sec]: Control: [-0.778600022505284, 0.7977771903843505] is applied to the system.
# Time 4.72 [sec]: New BIC control is available to the controller.
# Time 4.72 [sec]: Control: [-0.05624042512630066, 0.169926146425862] is applied to the system.
# Time 4.74 [sec]: Control: [-0.05624042512630066, 0.169926146425862] is applied to the system.
# Time 4.76 [sec]: Control: [-0.05624042512630066, 0.169926146425862] is applied to the system.
# Time 4.78 [sec]: Control: [-0.05624042512630066, 0.169926146425862] is applied to the system.
# Time 4.80 [sec]: New measurement is obtained.
# Time 4.80 [sec]: New BIC control computation is scheduled.
# Time 4.80 [sec]: Control: [-0.05624042512630066, 0.169926146425862] is applied to the system.
# Time 4.82 [sec]: New BIC control is available to the controller.
# Time 4.82 [sec]: Control: [-3.0752727487441542, -3.424625642295517] is applied to the system.
# Time 4.84 [sec]: Control: [-3.0752727487441542, -3.424625642295517] is applied to the system.
# Time 4.86 [sec]: Control: [-3.0752727487441542, -3.424625642295517] is applied to the system.
# Time 4.88 [sec]: Control: [-3.0752727487441542, -3.424625642295517] is applied to the system.
# Time 4.90 [sec]: New BIC control computation is scheduled.
# Time 4.90 [sec]: Control: [-3.0752727487441542, -3.424625642295517] is applied to the system.
# Time 4.92 [sec]: New BIC control is available to the controller.
# Time 4.92 [sec]: Control: [-1.9902357882011088, -2.375413167001436] is applied to the system.
# Time 4.94 [sec]: Control: [-1.9902357882011088, -2.375413167001436] is applied to the system.
# Time 4.96 [sec]: Control: [-1.9902357882011088, -2.375413167001436] is applied to the system.
# Time 4.98 [sec]: Control: [-1.9902357882011088, -2.375413167001436] is applied to the system.
# Time 5.00 [sec]: New BIC control computation is scheduled.
# Time 5.00 [sec]: Control: [-1.9902357882011088, -2.375413167001436] is applied to the system.
# Time 5.02 [sec]: New BIC control is available to the controller.
# Time 5.02 [sec]: Control: [-0.7596045517839327, -1.4777379214145192] is applied to the system.
# Time 5.04 [sec]: Control: [-0.7596045517839327, -1.4777379214145192] is applied to the system.
# Time 5.06 [sec]: Control: [-0.7596045517839327, -1.4777379214145192] is applied to the system.
# Time 5.08 [sec]: Control: [-0.7596045517839327, -1.4777379214145192] is applied to the system.
# Time 5.10 [sec]: New BIC control computation is scheduled.
# Time 5.10 [sec]: Control: [-0.7596045517839327, -1.4777379214145192] is applied to the system.
# Time 5.12 [sec]: New BIC control is available to the controller.
# Time 5.12 [sec]: Control: [0.007650677721248263, -0.9636558922045773] is applied to the system.
# Time 5.14 [sec]: Control: [0.007650677721248263, -0.9636558922045773] is applied to the system.
# Time 5.16 [sec]: Control: [0.007650677721248263, -0.9636558922045773] is applied to the system.
# Time 5.18 [sec]: Control: [0.007650677721248263, -0.9636558922045773] is applied to the system.
# Time 5.20 [sec]: New measurement is obtained.
# Time 5.20 [sec]: New BIC control computation is scheduled.
# Time 5.20 [sec]: Control: [0.007650677721248263, -0.9636558922045773] is applied to the system.
# Time 5.22 [sec]: New BIC control is available to the controller.
# Time 5.22 [sec]: Control: [2.161119480656051, -0.344572381352328] is applied to the system.
# Time 5.24 [sec]: Control: [2.161119480656051, -0.344572381352328] is applied to the system.
# Time 5.26 [sec]: Control: [2.161119480656051, -0.344572381352328] is applied to the system.
# Time 5.28 [sec]: Control: [2.161119480656051, -0.344572381352328] is applied to the system.
# Time 5.30 [sec]: New BIC control computation is scheduled.
# Time 5.30 [sec]: Control: [2.161119480656051, -0.344572381352328] is applied to the system.
# Time 5.32 [sec]: New BIC control is available to the controller.
# Time 5.32 [sec]: Control: [1.8304675284235545, -0.34350898538720454] is applied to the system.
# Time 5.34 [sec]: Control: [1.8304675284235545, -0.34350898538720454] is applied to the system.
# Time 5.36 [sec]: Control: [1.8304675284235545, -0.34350898538720454] is applied to the system.
# Time 5.38 [sec]: Control: [1.8304675284235545, -0.34350898538720454] is applied to the system.
# Time 5.40 [sec]: New BIC control computation is scheduled.
# Time 5.40 [sec]: Control: [1.8304675284235545, -0.34350898538720454] is applied to the system.
# Time 5.42 [sec]: New BIC control is available to the controller.
# Time 5.42 [sec]: Control: [1.407278860565131, -0.4270911709327532] is applied to the system.
# Time 5.44 [sec]: Control: [1.407278860565131, -0.4270911709327532] is applied to the system.
# Time 5.46 [sec]: Control: [1.407278860565131, -0.4270911709327532] is applied to the system.
# Time 5.48 [sec]: Control: [1.407278860565131, -0.4270911709327532] is applied to the system.
# Time 5.50 [sec]: New BIC control computation is scheduled.
# Time 5.50 [sec]: Control: [1.407278860565131, -0.4270911709327532] is applied to the system.
# Time 5.52 [sec]: New BIC control is available to the controller.
# Time 5.52 [sec]: Control: [1.1356067738529245, -0.413548839144115] is applied to the system.
# Time 5.54 [sec]: Control: [1.1356067738529245, -0.413548839144115] is applied to the system.
# Time 5.56 [sec]: Control: [1.1356067738529245, -0.413548839144115] is applied to the system.
# Time 5.58 [sec]: Control: [1.1356067738529245, -0.413548839144115] is applied to the system.
# Time 5.60 [sec]: New measurement is obtained.
# Time 5.60 [sec]: New BIC control computation is scheduled.
# Time 5.60 [sec]: Control: [1.1356067738529245, -0.413548839144115] is applied to the system.
# Time 5.62 [sec]: New BIC control is available to the controller.
# Time 5.62 [sec]: Control: [2.1755711267593054, 0.5624326825051588] is applied to the system.
# Time 5.64 [sec]: Control: [2.1755711267593054, 0.5624326825051588] is applied to the system.
# Time 5.66 [sec]: Control: [2.1755711267593054, 0.5624326825051588] is applied to the system.
# Time 5.68 [sec]: Control: [2.1755711267593054, 0.5624326825051588] is applied to the system.
# Time 5.70 [sec]: New BIC control computation is scheduled.
# Time 5.70 [sec]: Control: [2.1755711267593054, 0.5624326825051588] is applied to the system.
# Time 5.72 [sec]: New BIC control is available to the controller.
# Time 5.72 [sec]: Control: [1.8320814912375614, 0.5531488634126152] is applied to the system.
# Time 5.74 [sec]: Control: [1.8320814912375614, 0.5531488634126152] is applied to the system.
# Time 5.76 [sec]: Control: [1.8320814912375614, 0.5531488634126152] is applied to the system.
# Time 5.78 [sec]: Control: [1.8320814912375614, 0.5531488634126152] is applied to the system.
# Time 5.80 [sec]: New BIC control computation is scheduled.
# Time 5.80 [sec]: Control: [1.8320814912375614, 0.5531488634126152] is applied to the system.
# Time 5.82 [sec]: New BIC control is available to the controller.
# Time 5.82 [sec]: Control: [1.4757677318677176, 0.5101188604015254] is applied to the system.
# Time 5.84 [sec]: Control: [1.4757677318677176, 0.5101188604015254] is applied to the system.
# Time 5.86 [sec]: Control: [1.4757677318677176, 0.5101188604015254] is applied to the system.
# Time 5.88 [sec]: Control: [1.4757677318677176, 0.5101188604015254] is applied to the system.
# Time 5.90 [sec]: New BIC control computation is scheduled.
# Time 5.90 [sec]: Control: [1.4757677318677176, 0.5101188604015254] is applied to the system.
# Time 5.92 [sec]: New BIC control is available to the controller.
# Time 5.92 [sec]: Control: [1.15259319541454, 0.46646228661695577] is applied to the system.
# Time 5.94 [sec]: Control: [1.15259319541454, 0.46646228661695577] is applied to the system.
# Time 5.96 [sec]: Control: [1.15259319541454, 0.46646228661695577] is applied to the system.
# Time 5.98 [sec]: Control: [1.15259319541454, 0.46646228661695577] is applied to the system.
# Time 6.00 [sec]: New measurement is obtained.
# Time 6.00 [sec]: New BIC control computation is scheduled.
# Time 6.00 [sec]: Control: [1.15259319541454, 0.46646228661695577] is applied to the system.
# Time 6.02 [sec]: New BIC control is available to the controller.
# Time 6.02 [sec]: Control: [1.3256743769019115, 0.42372314719650633] is applied to the system.
# Time 6.04 [sec]: Control: [1.3256743769019115, 0.42372314719650633] is applied to the system.
# Time 6.06 [sec]: Control: [1.3256743769019115, 0.42372314719650633] is applied to the system.
# Time 6.08 [sec]: Control: [1.3256743769019115, 0.42372314719650633] is applied to the system.
# Time 6.10 [sec]: New BIC control computation is scheduled.
# Time 6.10 [sec]: Control: [1.3256743769019115, 0.42372314719650633] is applied to the system.
# Time 6.12 [sec]: New BIC control is available to the controller.
# Time 6.12 [sec]: Control: [1.0115418041485413, 0.38229266055881517] is applied to the system.
# Time 6.14 [sec]: Control: [1.0115418041485413, 0.38229266055881517] is applied to the system.
# Time 6.16 [sec]: Control: [1.0115418041485413, 0.38229266055881517] is applied to the system.
# Time 6.18 [sec]: Control: [1.0115418041485413, 0.38229266055881517] is applied to the system.
# Time 6.20 [sec]: New BIC control computation is scheduled.
# Time 6.20 [sec]: Control: [1.0115418041485413, 0.38229266055881517] is applied to the system.
# Time 6.22 [sec]: New BIC control is available to the controller.
# Time 6.22 [sec]: Control: [0.7158764194127967, 0.34245891647311794] is applied to the system.
# Time 6.24 [sec]: Control: [0.7158764194127967, 0.34245891647311794] is applied to the system.
# Time 6.26 [sec]: Control: [0.7158764194127967, 0.34245891647311794] is applied to the system.
# Time 6.28 [sec]: Control: [0.7158764194127967, 0.34245891647311794] is applied to the system.
# Time 6.30 [sec]: New BIC control computation is scheduled.
# Time 6.30 [sec]: Control: [0.7158764194127967, 0.34245891647311794] is applied to the system.
# Time 6.32 [sec]: New BIC control is available to the controller.
# Time 6.32 [sec]: Control: [0.454210031580963, 0.3044489122224194] is applied to the system.
# Time 6.34 [sec]: Control: [0.454210031580963, 0.3044489122224194] is applied to the system.
# Time 6.36 [sec]: Control: [0.454210031580963, 0.3044489122224194] is applied to the system.
# Time 6.38 [sec]: Control: [0.454210031580963, 0.3044489122224194] is applied to the system.
# Time 6.40 [sec]: New measurement is obtained.
# Time 6.40 [sec]: New BIC control computation is scheduled.
# Time 6.40 [sec]: Control: [0.454210031580963, 0.3044489122224194] is applied to the system.
# Time 6.42 [sec]: New BIC control is available to the controller.
# Time 6.42 [sec]: Control: [0.6919262319063887, 0.26843581480993894] is applied to the system.
# Time 6.44 [sec]: Control: [0.6919262319063887, 0.26843581480993894] is applied to the system.
# Time 6.46 [sec]: Control: [0.6919262319063887, 0.26843581480993894] is applied to the system.
# Time 6.48 [sec]: Control: [0.6919262319063887, 0.26843581480993894] is applied to the system.
# Time 6.50 [sec]: New BIC control computation is scheduled.
# Time 6.50 [sec]: Control: [0.6919262319063887, 0.26843581480993894] is applied to the system.
# Time 6.52 [sec]: New BIC control is available to the controller.
# Time 6.52 [sec]: Control: [0.4365406832572915, 0.23454481104937566] is applied to the system.
# Time 6.54 [sec]: Control: [0.4365406832572915, 0.23454481104937566] is applied to the system.
# Time 6.56 [sec]: Control: [0.4365406832572915, 0.23454481104937566] is applied to the system.
# Time 6.58 [sec]: Control: [0.4365406832572915, 0.23454481104937566] is applied to the system.
# Time 6.60 [sec]: New BIC control computation is scheduled.
# Time 6.60 [sec]: Control: [0.4365406832572915, 0.23454481104937566] is applied to the system.
# Time 6.62 [sec]: New BIC control is available to the controller.
# Time 6.62 [sec]: Control: [0.19760532784070547, 0.2028585790450483] is applied to the system.
# Time 6.64 [sec]: Control: [0.19760532784070547, 0.2028585790450483] is applied to the system.
# Time 6.66 [sec]: Control: [0.19760532784070547, 0.2028585790450483] is applied to the system.
# Time 6.68 [sec]: Control: [0.19760532784070547, 0.2028585790450483] is applied to the system.
# Time 6.70 [sec]: New BIC control computation is scheduled.
# Time 6.70 [sec]: Control: [0.19760532784070547, 0.2028585790450483] is applied to the system.
# Time 6.72 [sec]: New BIC control is available to the controller.
# Time 6.72 [sec]: Control: [-0.009581694915680129, 0.17342251733349362] is applied to the system.
# Time 6.74 [sec]: Control: [-0.009581694915680129, 0.17342251733349362] is applied to the system.
# Time 6.76 [sec]: Control: [-0.009581694915680129, 0.17342251733349362] is applied to the system.
# Time 6.78 [sec]: Control: [-0.009581694915680129, 0.17342251733349362] is applied to the system.
# Time 6.80 [sec]: New measurement is obtained.
# Time 6.80 [sec]: New BIC control computation is scheduled.
# Time 6.80 [sec]: Control: [-0.009581694915680129, 0.17342251733349362] is applied to the system.
# Time 6.82 [sec]: New BIC control is available to the controller.
# Time 6.82 [sec]: Control: [0.2781478999697157, 0.14624958535556726] is applied to the system.
# Time 6.84 [sec]: Control: [0.2781478999697157, 0.14624958535556726] is applied to the system.
# Time 6.86 [sec]: Control: [0.2781478999697157, 0.14624958535556726] is applied to the system.
# Time 6.88 [sec]: Control: [0.2781478999697157, 0.14624958535556726] is applied to the system.
# Time 6.90 [sec]: New BIC control computation is scheduled.
# Time 6.90 [sec]: Control: [0.2781478999697157, 0.14624958535556726] is applied to the system.
# Time 6.92 [sec]: New BIC control is available to the controller.
# Time 6.92 [sec]: Control: [0.07215287565376229, 0.12132486105706104] is applied to the system.
# Time 6.94 [sec]: Control: [0.07215287565376229, 0.12132486105706104] is applied to the system.
# Time 6.96 [sec]: Control: [0.07215287565376229, 0.12132486105706104] is applied to the system.
# Time 6.98 [sec]: Control: [0.07215287565376229, 0.12132486105706104] is applied to the system.
# Time 7.00 [sec]: New BIC control computation is scheduled.
# Time 7.00 [sec]: Control: [0.07215287565376229, 0.12132486105706104] is applied to the system.
# Time 7.02 [sec]: New BIC control is available to the controller.
# Time 7.02 [sec]: Control: [-0.12028197944865138, 0.09860973529550335] is applied to the system.
# Time 7.04 [sec]: Control: [-0.12028197944865138, 0.09860973529550335] is applied to the system.
# Time 7.06 [sec]: Control: [-0.12028197944865138, 0.09860973529550335] is applied to the system.
# Time 7.08 [sec]: Control: [-0.12028197944865138, 0.09860973529550335] is applied to the system.
# Time 7.10 [sec]: New BIC control computation is scheduled.
# Time 7.10 [sec]: Control: [-0.12028197944865138, 0.09860973529550335] is applied to the system.
# Time 7.12 [sec]: New BIC control is available to the controller.
# Time 7.12 [sec]: Control: [-0.28403649979503626, 0.07804578628446784] is applied to the system.
# Time 7.14 [sec]: Control: [-0.28403649979503626, 0.07804578628446784] is applied to the system.
# Time 7.16 [sec]: Control: [-0.28403649979503626, 0.07804578628446784] is applied to the system.
# Time 7.18 [sec]: Control: [-0.28403649979503626, 0.07804578628446784] is applied to the system.
# Time 7.20 [sec]: New measurement is obtained.
# Time 7.20 [sec]: New BIC control computation is scheduled.
# Time 7.20 [sec]: Control: [-0.28403649979503626, 0.07804578628446784] is applied to the system.
# Time 7.22 [sec]: New BIC control is available to the controller.
# Time 7.22 [sec]: Control: [0.032863970694032456, 0.05955832445839842] is applied to the system.
# Time 7.24 [sec]: Control: [0.032863970694032456, 0.05955832445839842] is applied to the system.
# Time 7.26 [sec]: Control: [0.032863970694032456, 0.05955832445839842] is applied to the system.
# Time 7.28 [sec]: Control: [0.032863970694032456, 0.05955832445839842] is applied to the system.
# Time 7.30 [sec]: New BIC control computation is scheduled.
# Time 7.30 [sec]: Control: [0.032863970694032456, 0.05955832445839842] is applied to the system.
# Time 7.32 [sec]: New BIC control is available to the controller.
# Time 7.32 [sec]: Control: [-0.13460498474340504, 0.04305957337587443] is applied to the system.
# Time 7.34 [sec]: Control: [-0.13460498474340504, 0.04305957337587443] is applied to the system.
# Time 7.36 [sec]: Control: [-0.13460498474340504, 0.04305957337587443] is applied to the system.
# Time 7.38 [sec]: Control: [-0.13460498474340504, 0.04305957337587443] is applied to the system.
# Time 7.40 [sec]: New BIC control computation is scheduled.
# Time 7.40 [sec]: Control: [-0.13460498474340504, 0.04305957337587443] is applied to the system.
# Time 7.42 [sec]: New BIC control is available to the controller.
# Time 7.42 [sec]: Control: [-0.2913393165493784, 0.028451606830833892] is applied to the system.
# Time 7.44 [sec]: Control: [-0.2913393165493784, 0.028451606830833892] is applied to the system.
# Time 7.46 [sec]: Control: [-0.2913393165493784, 0.028451606830833892] is applied to the system.
# Time 7.48 [sec]: Control: [-0.2913393165493784, 0.028451606830833892] is applied to the system.
# Time 7.50 [sec]: New BIC control computation is scheduled.
# Time 7.50 [sec]: Control: [-0.2913393165493784, 0.028451606830833892] is applied to the system.
# Time 7.52 [sec]: New BIC control is available to the controller.
# Time 7.52 [sec]: Control: [-0.42257680545108484, 0.015628921514593545] is applied to the system.
# Time 7.54 [sec]: Control: [-0.42257680545108484, 0.015628921514593545] is applied to the system.
# Time 7.56 [sec]: Control: [-0.42257680545108484, 0.015628921514593545] is applied to the system.
# Time 7.58 [sec]: Control: [-0.42257680545108484, 0.015628921514593545] is applied to the system.
# Time 7.60 [sec]: New measurement is obtained.
# Time 7.60 [sec]: New BIC control computation is scheduled.
# Time 7.60 [sec]: Control: [-0.42257680545108484, 0.015628921514593545] is applied to the system.
# Time 7.62 [sec]: New BIC control is available to the controller.
# Time 7.62 [sec]: Control: [-0.10114525947028667, 0.004480746200953641] is applied to the system.
# Time 7.64 [sec]: Control: [-0.10114525947028667, 0.004480746200953641] is applied to the system.
# Time 7.66 [sec]: Control: [-0.10114525947028667, 0.004480746200953641] is applied to the system.
# Time 7.68 [sec]: Control: [-0.10114525947028667, 0.004480746200953641] is applied to the system.
# Time 7.70 [sec]: New BIC control computation is scheduled.
# Time 7.70 [sec]: Control: [-0.10114525947028667, 0.004480746200953641] is applied to the system.
# Time 7.72 [sec]: New BIC control is available to the controller.
# Time 7.72 [sec]: Control: [-0.23917443331712593, -0.0051069089618745985] is applied to the system.
# Time 7.74 [sec]: Control: [-0.23917443331712593, -0.0051069089618745985] is applied to the system.
# Time 7.76 [sec]: Control: [-0.23917443331712593, -0.0051069089618745985] is applied to the system.
# Time 7.78 [sec]: Control: [-0.23917443331712593, -0.0051069089618745985] is applied to the system.
# Time 7.80 [sec]: New BIC control computation is scheduled.
# Time 7.80 [sec]: Control: [-0.23917443331712593, -0.0051069089618745985] is applied to the system.
# Time 7.82 [sec]: New BIC control is available to the controller.
# Time 7.82 [sec]: Control: [-0.36870007802975063, -0.013249499057216773] is applied to the system.
# Time 7.84 [sec]: Control: [-0.36870007802975063, -0.013249499057216773] is applied to the system.
# Time 7.86 [sec]: Control: [-0.36870007802975063, -0.013249499057216773] is applied to the system.
# Time 7.88 [sec]: Control: [-0.36870007802975063, -0.013249499057216773] is applied to the system.
# Time 7.90 [sec]: New BIC control computation is scheduled.
# Time 7.90 [sec]: Control: [-0.36870007802975063, -0.013249499057216773] is applied to the system.
# Time 7.92 [sec]: New BIC control is available to the controller.
# Time 7.92 [sec]: Control: [-0.47574579755027857, -0.020062385793824054] is applied to the system.
# Time 7.94 [sec]: Control: [-0.47574579755027857, -0.020062385793824054] is applied to the system.
# Time 7.96 [sec]: Control: [-0.47574579755027857, -0.020062385793824054] is applied to the system.
# Time 7.98 [sec]: Control: [-0.47574579755027857, -0.020062385793824054] is applied to the system.
# Time 8.00 [sec]: New measurement is obtained.
# Time 8.00 [sec]: New BIC control computation is scheduled.
# Time 8.00 [sec]: Control: [-0.47574579755027857, -0.020062385793824054] is applied to the system.
# Time 8.02 [sec]: New BIC control is available to the controller.
# Time 8.02 [sec]: Control: [-0.1765536278557704, -0.025659539455043342] is applied to the system.
# Time 8.04 [sec]: Control: [-0.1765536278557704, -0.025659539455043342] is applied to the system.
# Time 8.06 [sec]: Control: [-0.1765536278557704, -0.025659539455043342] is applied to the system.
# Time 8.08 [sec]: Control: [-0.1765536278557704, -0.025659539455043342] is applied to the system.
# Time 8.10 [sec]: New BIC control computation is scheduled.
# Time 8.10 [sec]: Control: [-0.1765536278557704, -0.025659539455043342] is applied to the system.
# Time 8.12 [sec]: New BIC control is available to the controller.
# Time 8.12 [sec]: Control: [-0.2906880074030109, -0.030152427593334353] is applied to the system.
# Time 8.14 [sec]: Control: [-0.2906880074030109, -0.030152427593334353] is applied to the system.
# Time 8.16 [sec]: Control: [-0.2906880074030109, -0.030152427593334353] is applied to the system.
# Time 8.18 [sec]: Control: [-0.2906880074030109, -0.030152427593334353] is applied to the system.
# Time 8.20 [sec]: New BIC control computation is scheduled.
# Time 8.20 [sec]: Control: [-0.2906880074030109, -0.030152427593334353] is applied to the system.
# Time 8.22 [sec]: New BIC control is available to the controller.
# Time 8.22 [sec]: Control: [-0.39773964119197824, -0.033649072741428296] is applied to the system.
# Time 8.24 [sec]: Control: [-0.39773964119197824, -0.033649072741428296] is applied to the system.
# Time 8.26 [sec]: Control: [-0.39773964119197824, -0.033649072741428296] is applied to the system.
# Time 8.28 [sec]: Control: [-0.39773964119197824, -0.033649072741428296] is applied to the system.
# Time 8.30 [sec]: New BIC control computation is scheduled.
# Time 8.30 [sec]: Control: [-0.39773964119197824, -0.033649072741428296] is applied to the system.
# Time 8.32 [sec]: New BIC control is available to the controller.
# Time 8.32 [sec]: Control: [-0.4851778289595635, -0.03625334670525726] is applied to the system.
# Time 8.34 [sec]: Control: [-0.4851778289595635, -0.03625334670525726] is applied to the system.
# Time 8.36 [sec]: Control: [-0.4851778289595635, -0.03625334670525726] is applied to the system.
# Time 8.38 [sec]: Control: [-0.4851778289595635, -0.03625334670525726] is applied to the system.
# Time 8.40 [sec]: New measurement is obtained.
# Time 8.40 [sec]: New BIC control computation is scheduled.
# Time 8.40 [sec]: Control: [-0.4851778289595635, -0.03625334670525726] is applied to the system.
# Time 8.42 [sec]: New BIC control is available to the controller.
# Time 8.42 [sec]: Control: [-0.23497683247621132, -0.038064351841454604] is applied to the system.
# Time 8.44 [sec]: Control: [-0.23497683247621132, -0.038064351841454604] is applied to the system.
# Time 8.46 [sec]: Control: [-0.23497683247621132, -0.038064351841454604] is applied to the system.
# Time 8.48 [sec]: Control: [-0.23497683247621132, -0.038064351841454604] is applied to the system.
# Time 8.50 [sec]: New BIC control computation is scheduled.
# Time 8.50 [sec]: Control: [-0.23497683247621132, -0.038064351841454604] is applied to the system.
# Time 8.52 [sec]: New BIC control is available to the controller.
# Time 8.52 [sec]: Control: [-0.326732502976643, -0.03917597878528989] is applied to the system.
# Time 8.54 [sec]: Control: [-0.326732502976643, -0.03917597878528989] is applied to the system.
# Time 8.56 [sec]: Control: [-0.326732502976643, -0.03917597878528989] is applied to the system.
# Time 8.58 [sec]: Control: [-0.326732502976643, -0.03917597878528989] is applied to the system.
# Time 8.60 [sec]: New BIC control computation is scheduled.
# Time 8.60 [sec]: Control: [-0.326732502976643, -0.03917597878528989] is applied to the system.
# Time 8.62 [sec]: New BIC control is available to the controller.
# Time 8.62 [sec]: Control: [-0.41204521599216054, -0.03967658272600293] is applied to the system.
# Time 8.64 [sec]: Control: [-0.41204521599216054, -0.03967658272600293] is applied to the system.
# Time 8.66 [sec]: Control: [-0.41204521599216054, -0.03967658272600293] is applied to the system.
# Time 8.68 [sec]: Control: [-0.41204521599216054, -0.03967658272600293] is applied to the system.
# Time 8.70 [sec]: New BIC control computation is scheduled.
# Time 8.70 [sec]: Control: [-0.41204521599216054, -0.03967658272600293] is applied to the system.
# Time 8.72 [sec]: New BIC control is available to the controller.
# Time 8.72 [sec]: Control: [-0.4806486440241462, -0.03964875800982122] is applied to the system.
# Time 8.74 [sec]: Control: [-0.4806486440241462, -0.03964875800982122] is applied to the system.
# Time 8.76 [sec]: Control: [-0.4806486440241462, -0.03964875800982122] is applied to the system.
# Time 8.78 [sec]: Control: [-0.4806486440241462, -0.03964875800982122] is applied to the system.
# Time 8.80 [sec]: New measurement is obtained.
# Time 8.80 [sec]: New BIC control computation is scheduled.
# Time 8.80 [sec]: Control: [-0.4806486440241462, -0.03964875800982122] is applied to the system.
# Time 8.82 [sec]: New BIC control is available to the controller.
# Time 8.82 [sec]: Control: [-0.30213531779702396, -0.03916923881532315] is applied to the system.
# Time 8.84 [sec]: Control: [-0.30213531779702396, -0.03916923881532315] is applied to the system.
# Time 8.86 [sec]: Control: [-0.30213531779702396, -0.03916923881532315] is applied to the system.
# Time 8.88 [sec]: Control: [-0.30213531779702396, -0.03916923881532315] is applied to the system.
# Time 8.90 [sec]: New BIC control computation is scheduled.
# Time 8.90 [sec]: Control: [-0.30213531779702396, -0.03916923881532315] is applied to the system.
# Time 8.92 [sec]: New BIC control is available to the controller.
# Time 8.92 [sec]: Control: [-0.3697008946599403, -0.03830885733100359] is applied to the system.
# Time 8.94 [sec]: Control: [-0.3697008946599403, -0.03830885733100359] is applied to the system.
# Time 8.96 [sec]: Control: [-0.3697008946599403, -0.03830885733100359] is applied to the system.
# Time 8.98 [sec]: Control: [-0.3697008946599403, -0.03830885733100359] is applied to the system.
# Time 9.00 [sec]: New BIC control computation is scheduled.
# Time 9.00 [sec]: Control: [-0.3697008946599403, -0.03830885733100359] is applied to the system.
# Time 9.02 [sec]: New BIC control is available to the controller.
# Time 9.02 [sec]: Control: [-0.4309210725014714, -0.03713255016253961] is applied to the system.
# Time 9.04 [sec]: Control: [-0.4309210725014714, -0.03713255016253961] is applied to the system.
# Time 9.06 [sec]: Control: [-0.4309210725014714, -0.03713255016253961] is applied to the system.
# Time 9.08 [sec]: Control: [-0.4309210725014714, -0.03713255016253961] is applied to the system.
# Time 9.10 [sec]: New BIC control computation is scheduled.
# Time 9.10 [sec]: Control: [-0.4309210725014714, -0.03713255016253961] is applied to the system.
# Time 9.12 [sec]: New BIC control is available to the controller.
# Time 9.12 [sec]: Control: [-0.47859908986162686, -0.03569955630760063] is applied to the system.
# Time 9.14 [sec]: Control: [-0.47859908986162686, -0.03569955630760063] is applied to the system.
# Time 9.16 [sec]: Control: [-0.47859908986162686, -0.03569955630760063] is applied to the system.
# Time 9.18 [sec]: Control: [-0.47859908986162686, -0.03569955630760063] is applied to the system.
# Time 9.20 [sec]: New measurement is obtained.
# Time 9.20 [sec]: New BIC control computation is scheduled.
# Time 9.20 [sec]: Control: [-0.47859908986162686, -0.03569955630760063] is applied to the system.
# Time 9.22 [sec]: New BIC control is available to the controller.
# Time 9.22 [sec]: Control: [-0.3830575328666383, -0.03406343603054272] is applied to the system.
# Time 9.24 [sec]: Control: [-0.3830575328666383, -0.03406343603054272] is applied to the system.
# Time 9.26 [sec]: Control: [-0.3830575328666383, -0.03406343603054272] is applied to the system.
# Time 9.28 [sec]: Control: [-0.3830575328666383, -0.03406343603054272] is applied to the system.
# Time 9.30 [sec]: New BIC control computation is scheduled.
# Time 9.30 [sec]: Control: [-0.3830575328666383, -0.03406343603054272] is applied to the system.
# Time 9.32 [sec]: New BIC control is available to the controller.
# Time 9.32 [sec]: Control: [-0.4232747593063461, -0.032272367176549105] is applied to the system.
# Time 9.34 [sec]: Control: [-0.4232747593063461, -0.032272367176549105] is applied to the system.
# Time 9.36 [sec]: Control: [-0.4232747593063461, -0.032272367176549105] is applied to the system.
# Time 9.38 [sec]: Control: [-0.4232747593063461, -0.032272367176549105] is applied to the system.
# Time 9.40 [sec]: New BIC control computation is scheduled.
# Time 9.40 [sec]: Control: [-0.4232747593063461, -0.032272367176549105] is applied to the system.
# Time 9.42 [sec]: New BIC control is available to the controller.
# Time 9.42 [sec]: Control: [-0.45714499221815047, -0.030369371796102614] is applied to the system.
# Time 9.44 [sec]: Control: [-0.45714499221815047, -0.030369371796102614] is applied to the system.
# Time 9.46 [sec]: Control: [-0.45714499221815047, -0.030369371796102614] is applied to the system.
# Time 9.48 [sec]: Control: [-0.45714499221815047, -0.030369371796102614] is applied to the system.
# Time 9.50 [sec]: New BIC control computation is scheduled.
# Time 9.50 [sec]: Control: [-0.45714499221815047, -0.030369371796102614] is applied to the system.
# Time 9.52 [sec]: New BIC control is available to the controller.
# Time 9.52 [sec]: Control: [-0.48101186097395743, -0.028392470027689177] is applied to the system.
# Time 9.54 [sec]: Control: [-0.48101186097395743, -0.028392470027689177] is applied to the system.
# Time 9.56 [sec]: Control: [-0.48101186097395743, -0.028392470027689177] is applied to the system.
# Time 9.58 [sec]: Control: [-0.48101186097395743, -0.028392470027689177] is applied to the system.
# Time 9.60 [sec]: New measurement is obtained.
# Time 9.60 [sec]: New BIC control computation is scheduled.
# Time 9.60 [sec]: Control: [-0.48101186097395743, -0.028392470027689177] is applied to the system.
# Time 9.62 [sec]: New BIC control is available to the controller.
# Time 9.62 [sec]: Control: [-0.4564525838701845, -0.026375092731571115] is applied to the system.
# Time 9.64 [sec]: Control: [-0.4564525838701845, -0.026375092731571115] is applied to the system.
# Time 9.66 [sec]: Control: [-0.4564525838701845, -0.026375092731571115] is applied to the system.
# Time 9.68 [sec]: Control: [-0.4564525838701845, -0.026375092731571115] is applied to the system.
# Time 9.70 [sec]: New BIC control computation is scheduled.
# Time 9.70 [sec]: Control: [-0.4564525838701845, -0.026375092731571115] is applied to the system.
# Time 9.72 [sec]: New BIC control is available to the controller.
# Time 9.72 [sec]: Control: [-0.46829659893876396, -0.024346265882317863] is applied to the system.
# Time 9.74 [sec]: Control: [-0.46829659893876396, -0.024346265882317863] is applied to the system.
# Time 9.76 [sec]: Control: [-0.46829659893876396, -0.024346265882317863] is applied to the system.
# Time 9.78 [sec]: Control: [-0.46829659893876396, -0.024346265882317863] is applied to the system.
# Time 9.80 [sec]: New BIC control computation is scheduled.
# Time 9.80 [sec]: Control: [-0.46829659893876396, -0.024346265882317863] is applied to the system.
# Time 9.82 [sec]: New BIC control is available to the controller.
# Time 9.82 [sec]: Control: [-0.47435213688509364, -0.022330980498100235] is applied to the system.
# Time 9.84 [sec]: Control: [-0.47435213688509364, -0.022330980498100235] is applied to the system.
# Time 9.86 [sec]: Control: [-0.47435213688509364, -0.022330980498100235] is applied to the system.
# Time 9.88 [sec]: Control: [-0.47435213688509364, -0.022330980498100235] is applied to the system.
# Time 9.90 [sec]: New BIC control computation is scheduled.
# Time 9.90 [sec]: Control: [-0.47435213688509364, -0.022330980498100235] is applied to the system.
# Time 9.92 [sec]: New BIC control is available to the controller.
# Time 9.92 [sec]: Control: [-0.4741247105980318, -0.02035042065900072] is applied to the system.
# Time 9.94 [sec]: Control: [-0.4741247105980318, -0.02035042065900072] is applied to the system.
# Time 9.96 [sec]: Control: [-0.4741247105980318, -0.02035042065900072] is applied to the system.
# Time 9.98 [sec]: Control: [-0.4741247105980318, -0.02035042065900072] is applied to the system.
# Time 10.00 [sec]: New measurement is obtained.

# %%
result.total_cnt_cost
# Out:
# 0.9428496202092838

# %%
result.total_pos_cost
# Out:
# 0.6899818870437487

# %%
result.total_col_cost
# Out:
# 42.83065976634475

# %%
result.total_cnt_cost + result.total_pos_cost + result.total_col_cost
# Out:
# 44.46349127359778

# %%
minimum([minimum(vcat([norm(get_position(w.e_state) - ap) for ap in values(w.ap_dict)], Inf))
                          for w in result.w_history])
# Out:
# 0.5037988008687359

# %%
make_gif(result, dtplot=0.02, fps=50, xlim=(-6., 6.), ylim=(-6., 6.), figsize=(600, 400), 
         legendfontsize=7, legend=:topright, markersize=5., filename="5_bic_synthetic.gif")
# Out:
# ┌ Warning: No prediction is available with BIC Controller
# └ @ RiskSensitiveSAC /home/haruki/Documents/2020-21_Autumn/RiskSensitiveSAC.jl/src/utils.jl:618
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:27
# ┌ Info: Saved animation to
# │   fn = /home/haruki/Documents/2020-21_Autumn/RiskSensitiveSAC.jl/notebook/5_bic_synthetic.gif
# └ @ Plots /home/haruki/.julia/packages/Plots/qZHsp/src/animation.jl:98
# Plots.AnimatedGif("/home/haruki/Documents/2020-21_Autumn/RiskSensitiveSAC.jl/notebook/5_bic_synthetic.gif")

# %%
save("5_bic_synthetic.jld2", "result", result)
