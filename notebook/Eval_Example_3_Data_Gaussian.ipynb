# %%
using Revise

ENV["PYCALL_JL_RUNTIME_PYTHON"] = Sys.which("python")
using FileIO
using JLD2
using RiskSensitiveSAC
# Out:
# ┌ Info: Number of Julia Thread(s): 1
# └ @ RiskSensitiveSAC /home/haruki/Documents/2020-21_Autumn/RiskSensitiveSAC.jl/src/RiskSensitiveSAC.jl:39
# ┌ Info: CUDA Device: GeForce RTX 2080 Ti
# └ @ RiskSensitiveSAC /home/haruki/Documents/2020-21_Autumn/RiskSensitiveSAC.jl/src/RiskSensitiveSAC.jl:40
# ┌ Info: Python executable used by PyCall: /home/haruki/Documents/2020-21_Autumn/RiskSensitiveSAC.jl/env_trajectron++/bin/python3.6
# └ @ RiskSensitiveSAC /home/haruki/Documents/2020-21_Autumn/RiskSensitiveSAC.jl/src/RiskSensitiveSAC.jl:41

# %% [markdown]
# # 1. Default

# %%
include("$(@__DIR__)/../scripts/default_params/params_data_gaussian.jl");

include("$(@__DIR__)/../scripts/parameter_setup.jl");

# %%
scene_loader, controller, w_init, measurement_schedule, target_trajectory, target_speed =
controller_setup(scene_param,
                 predictor_param,
                 prediction_device=prediction_device,
                 cost_param=cost_param,
                 cnt_param=cnt_param,
                 dtc=dtc,
                 ado_vel_dict=ado_vel_dict,
                 ego_pos_init_vec=ego_pos_init_vec,
                 ego_pos_goal_vec=ego_pos_goal_vec,
                 target_speed=target_speed,
                 sim_horizon=sim_horizon,
                 verbose=true);
# Out:
# Scene Mode: data
# Prediction Mode: gaussian
# Deterministic Prediction: false
# Loaded evaluation data from /home/haruki/Documents/2020-21_Autumn/RiskSensitiveSAC.jl/Trajectron-plus-plus/experiments/processed/eth_test.pkl
# Looking at the eth_test.pkl sequence, data_id 0, start_idx 905

# %%
result, ~, ~ = evaluate(scene_loader, controller, w_init, ego_pos_goal_vec,
                  target_speed, measurement_schedule, target_trajectory,
                  pos_error_replan, nominal_control=false);
# Out:
# ┌ Warning: Time 0.00 [sec]: SAC computation took 27.006 [sec], which exceeds the maximum computation time allowed.
# └ @ RiskSensitiveSAC /home/haruki/Documents/2020-21_Autumn/RiskSensitiveSAC.jl/src/rs_sac_controller.jl:731
# ┌ Warning: Time 0.00 [sec]: This evaluation iteration took 0.47 [sec], which exceeds dtc.
# └ @ RiskSensitiveSAC /home/haruki/Documents/2020-21_Autumn/RiskSensitiveSAC.jl/src/evaluation.jl:249
# ┌ Warning: Time 0.40 [sec]: This evaluation iteration took 0.28 [sec], which exceeds dtc.
# └ @ RiskSensitiveSAC /home/haruki/Documents/2020-21_Autumn/RiskSensitiveSAC.jl/src/evaluation.jl:249
# ┌ Warning: Time 7.62 [sec]: This evaluation iteration took 0.032 [sec], which exceeds dtc.
# └ @ RiskSensitiveSAC /home/haruki/Documents/2020-21_Autumn/RiskSensitiveSAC.jl/src/evaluation.jl:249

# %%
display_log(result.log)
# Out:
# Time 0.00 [sec]: New prediction is available to the controller.
# Time 0.00 [sec]: New SAC control computation is scheduled.
# Time 0.00 [sec]: New SAC control is available to the controller.
# Time 0.00 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.02 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.04 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.06 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.08 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.10 [sec]: New SAC control computation is scheduled.
# Time 0.10 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.12 [sec]: New SAC control is available to the controller.
# Time 0.12 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.14 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.16 [sec]: Control: [2.419818639755249, -4.3754401206970215] is applied to the system.
# Time 0.18 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.20 [sec]: New SAC control computation is scheduled.
# Time 0.20 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.22 [sec]: New SAC control is available to the controller.
# Time 0.22 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.24 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.26 [sec]: Control: [0.4803992211818695, -0.8770499229431152] is applied to the system.
# Time 0.28 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.30 [sec]: New SAC control computation is scheduled.
# Time 0.30 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.32 [sec]: New SAC control is available to the controller.
# Time 0.32 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.34 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.36 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.38 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.40 [sec]: New measurement is obtained.
# Time 0.40 [sec]: New prediction is scheduled.
# Time 0.40 [sec]: New SAC control computation is scheduled.
# Time 0.40 [sec]: Control: [0.16418418288230896, -0.25010204315185547] is applied to the system.
# Time 0.42 [sec]: New prediction is available to the controller.
# Time 0.42 [sec]: New SAC control is available to the controller.
# Time 0.42 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.44 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.46 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.48 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.50 [sec]: New SAC control computation is scheduled.
# Time 0.50 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.52 [sec]: New SAC control is available to the controller.
# Time 0.52 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.54 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.56 [sec]: Control: [-1.9678467512130737, -0.35718220472335815] is applied to the system.
# Time 0.58 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.60 [sec]: New SAC control computation is scheduled.
# Time 0.60 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.62 [sec]: New SAC control is available to the controller.
# Time 0.62 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.64 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.66 [sec]: Control: [3.022521734237671, -3.983009099960327] is applied to the system.
# Time 0.68 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.70 [sec]: New SAC control computation is scheduled.
# Time 0.70 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.72 [sec]: New SAC control is available to the controller.
# Time 0.72 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.74 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.76 [sec]: Control: [1.3015252351760864, -1.5185625553131104] is applied to the system.
# Time 0.78 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.80 [sec]: New measurement is obtained.
# Time 0.80 [sec]: New prediction is scheduled.
# Time 0.80 [sec]: New SAC control computation is scheduled.
# Time 0.80 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.82 [sec]: New prediction is available to the controller.
# Time 0.82 [sec]: New SAC control is available to the controller.
# Time 0.82 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.84 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.86 [sec]: Control: [0.20754648745059967, -0.2519296109676361] is applied to the system.
# Time 0.88 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.90 [sec]: New SAC control computation is scheduled.
# Time 0.90 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.92 [sec]: New SAC control is available to the controller.
# Time 0.92 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.94 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.96 [sec]: Control: [-1.4336018562316895, 3.734271764755249] is applied to the system.
# Time 0.98 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.00 [sec]: New SAC control computation is scheduled.
# Time 1.00 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.02 [sec]: New SAC control is available to the controller.
# Time 1.02 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.04 [sec]: Control: [0.8500237464904785, 4.927216053009033] is applied to the system.
# Time 1.06 [sec]: Control: [0.8500237464904785, 4.927216053009033] is applied to the system.
# Time 1.08 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.10 [sec]: New SAC control computation is scheduled.
# Time 1.10 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.12 [sec]: New SAC control is available to the controller.
# Time 1.12 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.14 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.16 [sec]: Control: [-1.9863470792770386, -0.23329249024391174] is applied to the system.
# Time 1.18 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.20 [sec]: New measurement is obtained.
# Time 1.20 [sec]: New prediction is scheduled.
# Time 1.20 [sec]: New SAC control computation is scheduled.
# Time 1.20 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.22 [sec]: New prediction is available to the controller.
# Time 1.22 [sec]: New SAC control is available to the controller.
# Time 1.22 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.24 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.26 [sec]: Control: [-0.9975640177726746, -0.06975730508565903] is applied to the system.
# Time 1.28 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.30 [sec]: New SAC control computation is scheduled.
# Time 1.30 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.32 [sec]: New SAC control is available to the controller.
# Time 1.32 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.34 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.36 [sec]: Control: [-1.9963347911834717, 0.12102589011192322] is applied to the system.
# Time 1.38 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.40 [sec]: New SAC control computation is scheduled.
# Time 1.40 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.42 [sec]: New SAC control is available to the controller.
# Time 1.42 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.44 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.46 [sec]: Control: [-1.9004387855529785, -0.18424037098884583] is applied to the system.
# Time 1.48 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.50 [sec]: New SAC control computation is scheduled.
# Time 1.50 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.52 [sec]: New SAC control is available to the controller.
# Time 1.52 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.54 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.56 [sec]: Control: [-0.47460612654685974, 0.01592140644788742] is applied to the system.
# Time 1.58 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.60 [sec]: New measurement is obtained.
# Time 1.60 [sec]: New prediction is scheduled.
# Time 1.60 [sec]: New SAC control computation is scheduled.
# Time 1.60 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.62 [sec]: New prediction is available to the controller.
# Time 1.62 [sec]: New SAC control is available to the controller.
# Time 1.62 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.64 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.66 [sec]: Control: [-0.15114711225032806, -0.04684361815452576] is applied to the system.
# Time 1.68 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.70 [sec]: New SAC control computation is scheduled.
# Time 1.70 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.72 [sec]: New SAC control is available to the controller.
# Time 1.72 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.74 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.76 [sec]: Control: [0.19945915043354034, 0.10170301049947739] is applied to the system.
# Time 1.78 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.80 [sec]: New SAC control computation is scheduled.
# Time 1.80 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.82 [sec]: New SAC control is available to the controller.
# Time 1.82 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.84 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.86 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.88 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.90 [sec]: New SAC control computation is scheduled.
# Time 1.90 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.92 [sec]: New SAC control is available to the controller.
# Time 1.92 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.94 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.96 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.98 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.00 [sec]: New measurement is obtained.
# Time 2.00 [sec]: New prediction is scheduled.
# Time 2.00 [sec]: New SAC control computation is scheduled.
# Time 2.00 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.02 [sec]: New prediction is available to the controller.
# Time 2.02 [sec]: New SAC control is available to the controller.
# Time 2.02 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.04 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.06 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.08 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.10 [sec]: New SAC control computation is scheduled.
# Time 2.10 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.12 [sec]: New SAC control is available to the controller.
# Time 2.12 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.14 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.16 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.18 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.20 [sec]: New SAC control computation is scheduled.
# Time 2.20 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.22 [sec]: New SAC control is available to the controller.
# Time 2.22 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.24 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.26 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.28 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.30 [sec]: New SAC control computation is scheduled.
# Time 2.30 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.32 [sec]: New SAC control is available to the controller.
# Time 2.32 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.34 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.36 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.38 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.40 [sec]: New measurement is obtained.
# Time 2.40 [sec]: New prediction is scheduled.
# Time 2.40 [sec]: New SAC control computation is scheduled.
# Time 2.40 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.42 [sec]: New prediction is available to the controller.
# Time 2.42 [sec]: New SAC control is available to the controller.
# Time 2.42 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.44 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.46 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.48 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.50 [sec]: New SAC control computation is scheduled.
# Time 2.50 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.52 [sec]: New SAC control is available to the controller.
# Time 2.52 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.54 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.56 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.58 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.60 [sec]: New SAC control computation is scheduled.
# Time 2.60 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.62 [sec]: New SAC control is available to the controller.
# Time 2.62 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.64 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.66 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.68 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.70 [sec]: New SAC control computation is scheduled.
# Time 2.70 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.72 [sec]: New SAC control is available to the controller.
# Time 2.72 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.74 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.76 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.78 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.80 [sec]: New measurement is obtained.
# Time 2.80 [sec]: New prediction is scheduled.
# Time 2.80 [sec]: New SAC control computation is scheduled.
# Time 2.80 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.82 [sec]: New prediction is available to the controller.
# Time 2.82 [sec]: New SAC control is available to the controller.
# Time 2.82 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.84 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.86 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.88 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.90 [sec]: New SAC control computation is scheduled.
# Time 2.90 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.92 [sec]: New SAC control is available to the controller.
# Time 2.92 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.94 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.96 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.98 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.00 [sec]: New SAC control computation is scheduled.
# Time 3.00 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.02 [sec]: New SAC control is available to the controller.
# Time 3.02 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.04 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.06 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.08 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.10 [sec]: New SAC control computation is scheduled.
# Time 3.10 [sec]: Control: [0.12055695056915283, -0.0863843560218811] is applied to the system.
# Time 3.12 [sec]: New SAC control is available to the controller.
# Time 3.12 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.14 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.16 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.18 [sec]: Control: [0.02593662030994892, -0.03223569318652153] is applied to the system.
# Time 3.20 [sec]: New measurement is obtained.
# Time 3.20 [sec]: New prediction is scheduled.
# Time 3.20 [sec]: New SAC control computation is scheduled.
# Time 3.20 [sec]: Control: [0.02593662030994892, -0.03223569318652153] is applied to the system.
# Time 3.22 [sec]: New prediction is available to the controller.
# Time 3.22 [sec]: New SAC control is available to the controller.
# Time 3.22 [sec]: Control: [0.02593662030994892, -0.03223569318652153] is applied to the system.
# Time 3.24 [sec]: Control: [0.04248744994401932, -0.05763475224375725] is applied to the system.
# Time 3.26 [sec]: Control: [0.20409047603607178, -0.1649145632982254] is applied to the system.
# Time 3.28 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.30 [sec]: New SAC control computation is scheduled.
# Time 3.30 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.32 [sec]: New SAC control is available to the controller.
# Time 3.32 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.34 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.36 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.38 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.40 [sec]: New SAC control computation is scheduled.
# Time 3.40 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.42 [sec]: New SAC control is available to the controller.
# Time 3.42 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.44 [sec]: Control: [-3.5154106616973877, 3.5555431842803955] is applied to the system.
# Time 3.46 [sec]: Control: [-3.5154106616973877, 3.5555431842803955] is applied to the system.
# Time 3.48 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.50 [sec]: New SAC control computation is scheduled.
# Time 3.50 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.52 [sec]: New SAC control is available to the controller.
# Time 3.52 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.54 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.56 [sec]: Control: [1.2637410163879395, -1.5501480102539062] is applied to the system.
# Time 3.58 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.60 [sec]: New measurement is obtained.
# Time 3.60 [sec]: New prediction is scheduled.
# Time 3.60 [sec]: New SAC control computation is scheduled.
# Time 3.60 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.62 [sec]: New prediction is available to the controller.
# Time 3.62 [sec]: New SAC control is available to the controller.
# Time 3.62 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.64 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.66 [sec]: Control: [0.05478455498814583, -0.3871558606624603] is applied to the system.
# Time 3.68 [sec]: Control: [-0.014707125723361969, -0.013521994464099407] is applied to the system.
# Time 3.70 [sec]: New SAC control computation is scheduled.
# Time 3.70 [sec]: Control: [0.12177758663892746, -0.12044133245944977] is applied to the system.
# Time 3.72 [sec]: New SAC control is available to the controller.
# Time 3.72 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.74 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.76 [sec]: Control: [-4.8497724533081055, 1.2164316177368164] is applied to the system.
# Time 3.78 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.80 [sec]: New SAC control computation is scheduled.
# Time 3.80 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.82 [sec]: New SAC control is available to the controller.
# Time 3.82 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.84 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.86 [sec]: Control: [3.512725591659546, -1.9133107662200928] is applied to the system.
# Time 3.88 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.90 [sec]: New SAC control computation is scheduled.
# Time 3.90 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.92 [sec]: New SAC control is available to the controller.
# Time 3.92 [sec]: Control: [0.09191697835922241, -0.10084009170532227] is applied to the system.
# Time 3.94 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.96 [sec]: Control: [1.0777722597122192, 1.6847572326660156] is applied to the system.
# Time 3.98 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.00 [sec]: New measurement is obtained.
# Time 4.00 [sec]: New prediction is scheduled.
# Time 4.00 [sec]: New SAC control computation is scheduled.
# Time 4.00 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.02 [sec]: New prediction is available to the controller.
# Time 4.02 [sec]: New SAC control is available to the controller.
# Time 4.02 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.04 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.06 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.08 [sec]: Control: [3.9006617069244385, 0.8859107494354248] is applied to the system.
# Time 4.10 [sec]: New SAC control computation is scheduled.
# Time 4.10 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.12 [sec]: New SAC control is available to the controller.
# Time 4.12 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.14 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.16 [sec]: Control: [-3.916958808898926, 0.810822606086731] is applied to the system.
# Time 4.18 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.20 [sec]: New SAC control computation is scheduled.
# Time 4.20 [sec]: Control: [-0.0, -2.0] is applied to the system.
# Time 4.22 [sec]: New SAC control is available to the controller.
# Time 4.22 [sec]: Control: [-0.0, -2.0] is applied to the system.
# Time 4.24 [sec]: Control: [-0.0, -2.0] is applied to the system.
# Time 4.26 [sec]: Control: [1.3738065958023071, 4.807562351226807] is applied to the system.
# Time 4.28 [sec]: Control: [-0.0, -2.0] is applied to the system.
# Time 4.30 [sec]: New SAC control computation is scheduled.
# Time 4.30 [sec]: Control: [-0.0, -2.0] is applied to the system.
# Time 4.32 [sec]: New SAC control is available to the controller.
# Time 4.32 [sec]: Control: [-0.0, -2.0] is applied to the system.
# Time 4.34 [sec]: Control: [-0.0, -2.0] is applied to the system.
# Time 4.36 [sec]: Control: [-0.0, -2.0] is applied to the system.
# Time 4.38 [sec]: Control: [-0.0, -2.0] is applied to the system.
# Time 4.40 [sec]: New measurement is obtained.
# Time 4.40 [sec]: New prediction is scheduled.
# Time 4.40 [sec]: New SAC control computation is scheduled.
# Time 4.40 [sec]: Control: [-0.0, -2.0] is applied to the system.
# Time 4.42 [sec]: New prediction is available to the controller.
# Time 4.42 [sec]: New SAC control is available to the controller.
# Time 4.42 [sec]: Control: [-0.0, -2.0] is applied to the system.
# Time 4.44 [sec]: Control: [-0.0, -2.0] is applied to the system.
# Time 4.46 [sec]: Control: [-0.0, -2.0] is applied to the system.
# Time 4.48 [sec]: Control: [-0.0, -2.0] is applied to the system.
# Time 4.50 [sec]: New SAC control computation is scheduled.
# Time 4.50 [sec]: Control: [-0.0, -2.0] is applied to the system.
# Time 4.52 [sec]: New SAC control is available to the controller.
# Time 4.52 [sec]: Control: [-0.0, -2.0] is applied to the system.
# Time 4.54 [sec]: Control: [-0.0, -2.0] is applied to the system.
# Time 4.56 [sec]: Control: [-3.9026596546173096, -3.125579357147217] is applied to the system.
# Time 4.58 [sec]: Control: [1.327249526977539, -1.4961313009262085] is applied to the system.
# Time 4.60 [sec]: New SAC control computation is scheduled.
# Time 4.60 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.62 [sec]: New SAC control is available to the controller.
# Time 4.62 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.64 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.66 [sec]: Control: [-4.8776397705078125, -1.0993781089782715] is applied to the system.
# Time 4.68 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.70 [sec]: New SAC control computation is scheduled.
# Time 4.70 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.72 [sec]: New SAC control is available to the controller.
# Time 4.72 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.74 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.76 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.78 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.80 [sec]: New measurement is obtained.
# Time 4.80 [sec]: New prediction is scheduled.
# Time 4.80 [sec]: New SAC control computation is scheduled.
# Time 4.80 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.82 [sec]: New prediction is available to the controller.
# Time 4.82 [sec]: New SAC control is available to the controller.
# Time 4.82 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.84 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.86 [sec]: Control: [-1.9983086585998535, 0.08223539590835571] is applied to the system.
# Time 4.88 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.90 [sec]: New SAC control computation is scheduled.
# Time 4.90 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 4.92 [sec]: New SAC control is available to the controller.
# Time 4.92 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 4.94 [sec]: Control: [0.5424719452857971, -4.970485210418701] is applied to the system.
# Time 4.96 [sec]: Control: [0.5424719452857971, -4.970485210418701] is applied to the system.
# Time 4.98 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 5.00 [sec]: New SAC control computation is scheduled.
# Time 5.00 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 5.02 [sec]: New SAC control is available to the controller.
# Time 5.02 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 5.04 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 5.06 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 5.08 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 5.10 [sec]: New SAC control computation is scheduled.
# Time 5.10 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 5.12 [sec]: New SAC control is available to the controller.
# Time 5.12 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 5.14 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 5.16 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 5.18 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 5.20 [sec]: New measurement is obtained.
# Time 5.20 [sec]: New prediction is scheduled.
# Time 5.20 [sec]: New SAC control computation is scheduled.
# Time 5.20 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 5.22 [sec]: New prediction is available to the controller.
# Time 5.22 [sec]: New SAC control is available to the controller.
# Time 5.22 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 5.24 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 5.26 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 5.28 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 5.30 [sec]: New SAC control computation is scheduled.
# Time 5.30 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 5.32 [sec]: New SAC control is available to the controller.
# Time 5.32 [sec]: Control: [4.343199253082275, 2.477220296859741] is applied to the system.
# Time 5.34 [sec]: Control: [4.343199253082275, 2.477220296859741] is applied to the system.
# Time 5.36 [sec]: Control: [-0.9834805727005005, -1.7414838075637817] is applied to the system.
# Time 5.38 [sec]: Control: [4.343199253082275, 2.477220296859741] is applied to the system.
# Time 5.40 [sec]: New SAC control computation is scheduled.
# Time 5.40 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.42 [sec]: New SAC control is available to the controller.
# Time 5.42 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.44 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.46 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.48 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.50 [sec]: New SAC control computation is scheduled.
# Time 5.50 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.52 [sec]: New SAC control is available to the controller.
# Time 5.52 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.54 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.56 [sec]: Control: [-2.358596086502075, -4.4087443351745605] is applied to the system.
# Time 5.58 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.60 [sec]: New measurement is obtained.
# Time 5.60 [sec]: New prediction is scheduled.
# Time 5.60 [sec]: New SAC control computation is scheduled.
# Time 5.60 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.62 [sec]: New prediction is available to the controller.
# Time 5.62 [sec]: New SAC control is available to the controller.
# Time 5.62 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.64 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.66 [sec]: Control: [-1.973106861114502, 0.32687804102897644] is applied to the system.
# Time 5.68 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.70 [sec]: New SAC control computation is scheduled.
# Time 5.70 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.72 [sec]: New SAC control is available to the controller.
# Time 5.72 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.74 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.76 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.78 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.80 [sec]: New SAC control computation is scheduled.
# Time 5.80 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.82 [sec]: New SAC control is available to the controller.
# Time 5.82 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.84 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.86 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.88 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.90 [sec]: New SAC control computation is scheduled.
# Time 5.90 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.92 [sec]: New SAC control is available to the controller.
# Time 5.92 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.94 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.96 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.98 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 6.00 [sec]: New measurement is obtained.
# Time 6.00 [sec]: New prediction is scheduled.
# Time 6.00 [sec]: New SAC control computation is scheduled.
# Time 6.00 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 6.02 [sec]: New prediction is available to the controller.
# Time 6.02 [sec]: New SAC control is available to the controller.
# Time 6.02 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 6.04 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 6.06 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 6.08 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 6.10 [sec]: New SAC control computation is scheduled.
# Time 6.10 [sec]: Control: [1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 6.12 [sec]: New SAC control is available to the controller.
# Time 6.12 [sec]: Control: [1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 6.14 [sec]: Control: [0.111873559653759, -4.998748302459717] is applied to the system.
# Time 6.16 [sec]: Control: [0.111873559653759, -4.998748302459717] is applied to the system.
# Time 6.18 [sec]: Control: [1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 6.20 [sec]: New SAC control computation is scheduled.
# Time 6.20 [sec]: Control: [1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 6.22 [sec]: New SAC control is available to the controller.
# Time 6.22 [sec]: Control: [1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 6.24 [sec]: Control: [1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 6.26 [sec]: Control: [1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 6.28 [sec]: Control: [1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 6.30 [sec]: New SAC control computation is scheduled.
# Time 6.30 [sec]: Control: [1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 6.32 [sec]: New SAC control is available to the controller.
# Time 6.32 [sec]: Control: [1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 6.34 [sec]: Control: [1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 6.36 [sec]: Control: [1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 6.38 [sec]: Control: [1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 6.40 [sec]: New measurement is obtained.
# Time 6.40 [sec]: New prediction is scheduled.
# Time 6.40 [sec]: New SAC control computation is scheduled.
# Time 6.40 [sec]: Control: [1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 6.42 [sec]: New prediction is available to the controller.
# Time 6.42 [sec]: New SAC control is available to the controller.
# Time 6.42 [sec]: Control: [1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 6.44 [sec]: Control: [1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 6.46 [sec]: Control: [1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 6.48 [sec]: Control: [1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 6.50 [sec]: New SAC control computation is scheduled.
# Time 6.50 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 6.52 [sec]: New SAC control is available to the controller.
# Time 6.52 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 6.54 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 6.56 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 6.58 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 6.60 [sec]: New SAC control computation is scheduled.
# Time 6.60 [sec]: Control: [-1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 6.62 [sec]: New SAC control is available to the controller.
# Time 6.62 [sec]: Control: [-1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 6.64 [sec]: Control: [-1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 6.66 [sec]: Control: [-1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 6.68 [sec]: Control: [-1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 6.70 [sec]: New SAC control computation is scheduled.
# Time 6.70 [sec]: Control: [-1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 6.72 [sec]: New SAC control is available to the controller.
# Time 6.72 [sec]: Control: [-1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 6.74 [sec]: Control: [-1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 6.76 [sec]: Control: [-1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 6.78 [sec]: Control: [-1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 6.80 [sec]: New measurement is obtained.
# Time 6.80 [sec]: New prediction is scheduled.
# Time 6.80 [sec]: New SAC control computation is scheduled.
# Time 6.80 [sec]: Control: [-1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 6.82 [sec]: New prediction is available to the controller.
# Time 6.82 [sec]: New SAC control is available to the controller.
# Time 6.82 [sec]: Control: [-1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 6.84 [sec]: Control: [-1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 6.86 [sec]: Control: [-1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 6.88 [sec]: Control: [-1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 6.90 [sec]: New SAC control computation is scheduled.
# Time 6.90 [sec]: Control: [-1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 6.92 [sec]: New SAC control is available to the controller.
# Time 6.92 [sec]: Control: [-1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 6.94 [sec]: Control: [-1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 6.96 [sec]: Control: [-1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 6.98 [sec]: Control: [-1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 7.00 [sec]: New SAC control computation is scheduled.
# Time 7.00 [sec]: Control: [-1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 7.02 [sec]: New SAC control is available to the controller.
# Time 7.02 [sec]: Control: [-1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 7.04 [sec]: Control: [-1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 7.06 [sec]: Control: [-1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 7.08 [sec]: Control: [-1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 7.10 [sec]: Position deviation: 2.0067. Target Trajectory is replanned.
# Time 7.10 [sec]: New SAC control computation is scheduled.
# Time 7.10 [sec]: Control: [-2.0, 0.0] is applied to the system.
# Time 7.12 [sec]: New SAC control is available to the controller.
# Time 7.12 [sec]: Control: [-2.0, 0.0] is applied to the system.
# Time 7.14 [sec]: Control: [-2.0, 0.0] is applied to the system.
# Time 7.16 [sec]: Control: [-2.193753719329834, -4.493043899536133] is applied to the system.
# Time 7.18 [sec]: Control: [-2.0, 0.0] is applied to the system.
# Time 7.20 [sec]: New measurement is obtained.
# Time 7.20 [sec]: New prediction is scheduled.
# Time 7.20 [sec]: New SAC control computation is scheduled.
# Time 7.20 [sec]: Control: [-2.0, 0.0] is applied to the system.
# Time 7.22 [sec]: New prediction is available to the controller.
# Time 7.22 [sec]: New SAC control is available to the controller.
# Time 7.22 [sec]: Control: [-2.0, 0.0] is applied to the system.
# Time 7.24 [sec]: Control: [-2.0, 0.0] is applied to the system.
# Time 7.26 [sec]: Control: [-2.0, 0.0] is applied to the system.
# Time 7.28 [sec]: Control: [-2.0, 0.0] is applied to the system.
# Time 7.30 [sec]: New SAC control computation is scheduled.
# Time 7.30 [sec]: Control: [-2.0, 0.0] is applied to the system.
# Time 7.32 [sec]: New SAC control is available to the controller.
# Time 7.32 [sec]: Control: [-2.0, 0.0] is applied to the system.
# Time 7.34 [sec]: Control: [-2.0, 0.0] is applied to the system.
# Time 7.36 [sec]: Control: [-2.0, 0.0] is applied to the system.
# Time 7.38 [sec]: Control: [-2.0, 0.0] is applied to the system.
# Time 7.40 [sec]: New SAC control computation is scheduled.
# Time 7.40 [sec]: Control: [-2.0, 0.0] is applied to the system.
# Time 7.42 [sec]: New SAC control is available to the controller.
# Time 7.42 [sec]: Control: [-2.0, 0.0] is applied to the system.
# Time 7.44 [sec]: Control: [-2.0, 0.0] is applied to the system.
# Time 7.46 [sec]: Control: [-2.0, 0.0] is applied to the system.
# Time 7.48 [sec]: Control: [-2.0, 0.0] is applied to the system.
# Time 7.50 [sec]: New SAC control computation is scheduled.
# Time 7.50 [sec]: Control: [-2.0, 0.0] is applied to the system.
# Time 7.52 [sec]: New SAC control is available to the controller.
# Time 7.52 [sec]: Control: [-2.0, 0.0] is applied to the system.
# Time 7.54 [sec]: Control: [-2.0, 0.0] is applied to the system.
# Time 7.56 [sec]: Control: [-2.0, 0.0] is applied to the system.
# Time 7.58 [sec]: Control: [-2.0, 0.0] is applied to the system.
# Time 7.60 [sec]: New measurement is obtained.
# Time 7.60 [sec]: New prediction is scheduled.
# Time 7.60 [sec]: New SAC control computation is scheduled.
# Time 7.60 [sec]: Control: [-2.0, 0.0] is applied to the system.
# Time 7.62 [sec]: New prediction is available to the controller.
# Time 7.62 [sec]: New SAC control is available to the controller.
# Time 7.62 [sec]: Control: [-2.0, 0.0] is applied to the system.
# Time 7.64 [sec]: Control: [-2.0, 0.0] is applied to the system.
# Time 7.66 [sec]: Control: [-2.0, 0.0] is applied to the system.
# Time 7.68 [sec]: Control: [-2.0, 0.0] is applied to the system.
# Time 7.70 [sec]: New SAC control computation is scheduled.
# Time 7.70 [sec]: Control: [-2.0, 0.0] is applied to the system.
# Time 7.72 [sec]: New SAC control is available to the controller.
# Time 7.72 [sec]: Control: [-4.908238410949707, 0.953518271446228] is applied to the system.
# Time 7.74 [sec]: Control: [3.182971954345703, 3.8559939861297607] is applied to the system.
# Time 7.76 [sec]: Control: [3.182971954345703, 3.8559939861297607] is applied to the system.
# Time 7.78 [sec]: Control: [-2.0, 0.0] is applied to the system.
# Time 7.80 [sec]: New SAC control computation is scheduled.
# Time 7.80 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 7.82 [sec]: New SAC control is available to the controller.
# Time 7.82 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 7.84 [sec]: Control: [1.683198094367981, 4.708168029785156] is applied to the system.
# Time 7.86 [sec]: Control: [1.683198094367981, 4.708168029785156] is applied to the system.
# Time 7.88 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 7.90 [sec]: New SAC control computation is scheduled.
# Time 7.90 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 7.92 [sec]: New SAC control is available to the controller.
# Time 7.92 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 7.94 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 7.96 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 7.98 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.00 [sec]: New measurement is obtained.
# Time 8.00 [sec]: New prediction is scheduled.
# Time 8.00 [sec]: New SAC control computation is scheduled.
# Time 8.00 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.02 [sec]: New prediction is available to the controller.
# Time 8.02 [sec]: New SAC control is available to the controller.
# Time 8.02 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.04 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.06 [sec]: Control: [0.17466305196285248, 0.9846282601356506] is applied to the system.
# Time 8.08 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.10 [sec]: New SAC control computation is scheduled.
# Time 8.10 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.12 [sec]: New SAC control is available to the controller.
# Time 8.12 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.14 [sec]: Control: [4.987711429595947, 0.35033565759658813] is applied to the system.
# Time 8.16 [sec]: Control: [4.987711429595947, 0.35033565759658813] is applied to the system.
# Time 8.18 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.20 [sec]: New SAC control computation is scheduled.
# Time 8.20 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.22 [sec]: New SAC control is available to the controller.
# Time 8.22 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.24 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.26 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.28 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.30 [sec]: New SAC control computation is scheduled.
# Time 8.30 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.32 [sec]: New SAC control is available to the controller.
# Time 8.32 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.34 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.36 [sec]: Control: [-1.7626358270645142, -0.9450474977493286] is applied to the system.
# Time 8.38 [sec]: Control: [1.5517150163650513, 4.7531232833862305] is applied to the system.
# Time 8.40 [sec]: New measurement is obtained.
# Time 8.40 [sec]: New prediction is scheduled.
# Time 8.40 [sec]: New SAC control computation is scheduled.
# Time 8.40 [sec]: Control: [1.5517150163650513, 4.7531232833862305] is applied to the system.
# Time 8.42 [sec]: New prediction is available to the controller.
# Time 8.42 [sec]: New SAC control is available to the controller.
# Time 8.42 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.44 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.46 [sec]: Control: [-0.26370927691459656, 3.991297721862793] is applied to the system.
# Time 8.48 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.50 [sec]: New SAC control computation is scheduled.
# Time 8.50 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.52 [sec]: New SAC control is available to the controller.
# Time 8.52 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.54 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.56 [sec]: Control: [2.4965507984161377, 4.332116603851318] is applied to the system.
# Time 8.58 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.60 [sec]: New SAC control computation is scheduled.
# Time 8.60 [sec]: Control: [-1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 8.62 [sec]: New SAC control is available to the controller.
# Time 8.62 [sec]: Control: [-1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 8.64 [sec]: Control: [-1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 8.66 [sec]: Control: [0.8858019113540649, -0.4640635550022125] is applied to the system.
# Time 8.68 [sec]: Control: [-1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 8.70 [sec]: New SAC control computation is scheduled.
# Time 8.70 [sec]: Control: [-1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 8.72 [sec]: New SAC control is available to the controller.
# Time 8.72 [sec]: Control: [-1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 8.74 [sec]: Control: [-1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 8.76 [sec]: Control: [0.06271777302026749, -0.2420051246881485] is applied to the system.
# Time 8.78 [sec]: Control: [-1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 8.80 [sec]: New measurement is obtained.
# Time 8.80 [sec]: New prediction is scheduled.
# Time 8.80 [sec]: New SAC control computation is scheduled.
# Time 8.80 [sec]: Control: [-1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 8.82 [sec]: New prediction is available to the controller.
# Time 8.82 [sec]: New SAC control is available to the controller.
# Time 8.82 [sec]: Control: [-1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 8.84 [sec]: Control: [-1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 8.86 [sec]: Control: [-1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 8.88 [sec]: Control: [-1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 8.90 [sec]: New SAC control computation is scheduled.
# Time 8.90 [sec]: Control: [0.0, 2.0] is applied to the system.
# Time 8.92 [sec]: New SAC control is available to the controller.
# Time 8.92 [sec]: Control: [0.0, 2.0] is applied to the system.
# Time 8.94 [sec]: Control: [0.0, 2.0] is applied to the system.
# Time 8.96 [sec]: Control: [0.0, 2.0] is applied to the system.
# Time 8.98 [sec]: Control: [0.0, 2.0] is applied to the system.
# Time 9.00 [sec]: New SAC control computation is scheduled.
# Time 9.00 [sec]: Control: [0.0, 2.0] is applied to the system.
# Time 9.02 [sec]: New SAC control is available to the controller.
# Time 9.02 [sec]: Control: [0.0, 2.0] is applied to the system.
# Time 9.04 [sec]: Control: [0.0, 2.0] is applied to the system.
# Time 9.06 [sec]: Control: [0.0, 2.0] is applied to the system.
# Time 9.08 [sec]: Control: [0.0, 2.0] is applied to the system.
# Time 9.10 [sec]: New SAC control computation is scheduled.
# Time 9.10 [sec]: Control: [0.0, 2.0] is applied to the system.
# Time 9.12 [sec]: New SAC control is available to the controller.
# Time 9.12 [sec]: Control: [0.0, 2.0] is applied to the system.
# Time 9.14 [sec]: Control: [0.0, 2.0] is applied to the system.
# Time 9.16 [sec]: Control: [0.0, 2.0] is applied to the system.
# Time 9.18 [sec]: Control: [0.0, 2.0] is applied to the system.
# Time 9.20 [sec]: New measurement is obtained.
# Time 9.20 [sec]: New prediction is scheduled.
# Time 9.20 [sec]: New SAC control computation is scheduled.
# Time 9.20 [sec]: Control: [0.0, 2.0] is applied to the system.
# Time 9.22 [sec]: New prediction is available to the controller.
# Time 9.22 [sec]: New SAC control is available to the controller.
# Time 9.22 [sec]: Control: [0.0, 2.0] is applied to the system.
# Time 9.24 [sec]: Control: [0.0, 2.0] is applied to the system.
# Time 9.26 [sec]: Control: [0.0, 2.0] is applied to the system.
# Time 9.28 [sec]: Control: [0.0, 2.0] is applied to the system.
# Time 9.30 [sec]: New SAC control computation is scheduled.
# Time 9.30 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 9.32 [sec]: New SAC control is available to the controller.
# Time 9.32 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 9.34 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 9.36 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 9.38 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 9.40 [sec]: New SAC control computation is scheduled.
# Time 9.40 [sec]: Control: [-0.0, -2.0] is applied to the system.
# Time 9.42 [sec]: New SAC control is available to the controller.
# Time 9.42 [sec]: Control: [-0.0, -2.0] is applied to the system.
# Time 9.44 [sec]: Control: [-0.0, -2.0] is applied to the system.
# Time 9.46 [sec]: Control: [-0.0, -2.0] is applied to the system.
# Time 9.48 [sec]: Control: [-0.0, -2.0] is applied to the system.
# Time 9.50 [sec]: New SAC control computation is scheduled.
# Time 9.50 [sec]: Control: [1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 9.52 [sec]: New SAC control is available to the controller.
# Time 9.52 [sec]: Control: [1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 9.54 [sec]: Control: [1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 9.56 [sec]: Control: [1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 9.58 [sec]: Control: [1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 9.60 [sec]: New measurement is obtained.
# Time 9.60 [sec]: New prediction is scheduled.
# Time 9.60 [sec]: New SAC control computation is scheduled.
# Time 9.60 [sec]: Control: [1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 9.62 [sec]: New prediction is available to the controller.
# Time 9.62 [sec]: New SAC control is available to the controller.
# Time 9.62 [sec]: Control: [1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 9.64 [sec]: Control: [1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 9.66 [sec]: Control: [1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 9.68 [sec]: Control: [1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 9.70 [sec]: New SAC control computation is scheduled.
# Time 9.70 [sec]: Control: [1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 9.72 [sec]: New SAC control is available to the controller.
# Time 9.72 [sec]: Control: [1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 9.74 [sec]: Control: [1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 9.76 [sec]: Control: [1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 9.78 [sec]: Control: [1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 9.80 [sec]: New SAC control computation is scheduled.
# Time 9.80 [sec]: Control: [4.470826148986816, 2.2386858463287354] is applied to the system.
# Time 9.82 [sec]: New SAC control is available to the controller.
# Time 9.82 [sec]: Control: [4.470826148986816, 2.2386858463287354] is applied to the system.
# Time 9.84 [sec]: Control: [4.470826148986816, 2.2386858463287354] is applied to the system.
# Time 9.86 [sec]: Control: [4.470826148986816, 2.2386858463287354] is applied to the system.
# Time 9.88 [sec]: Control: [-4.99993371963501, 0.025713343173265457] is applied to the system.
# Time 9.90 [sec]: New SAC control computation is scheduled.
# Time 9.90 [sec]: Control: [-4.99993371963501, 0.025713343173265457] is applied to the system.
# Time 9.92 [sec]: New SAC control is available to the controller.
# Time 9.92 [sec]: Control: [3.7244105339050293, -1.4590290784835815] is applied to the system.
# Time 9.94 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.96 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.98 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 10.00 [sec]: New measurement is obtained.

# %%
result.total_cnt_cost
# Out:
# 3.3910114798953153

# %%
result.total_pos_cost
# Out:
# 1.859907633288628

# %%
result.total_col_cost
# Out:
# 3.8685693998889854

# %%
result.total_cnt_cost + result.total_pos_cost + result.total_col_cost
# Out:
# 9.119488513072929

# %%
minimum([minimum(vcat([norm(get_position(w.e_state) - ap) for ap in values(w.ap_dict)], Inf))
                          for w in result.w_history])
# Out:
# 1.0375139419134705

# %%
make_gif(result, dtplot=0.02, fps=50, xlim=(-3. + -5.263534, 13. + -5.263534), 
         ylim=(0. + -5.314636, 10. + -5.314636), figsize=(600, 400), 
         legendfontsize=7, legend=:bottomright, markersize=5., filename="3_1_data_gaussian.gif")
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 0:02:11
# ┌ Info: Saved animation to
# │   fn = /home/haruki/Documents/2020-21_Autumn/RiskSensitiveSAC.jl/notebook/3_1_data_gaussian.gif
# └ @ Plots /home/haruki/.julia/packages/Plots/qZHsp/src/animation.jl:98
# Plots.AnimatedGif("/home/haruki/Documents/2020-21_Autumn/RiskSensitiveSAC.jl/notebook/3_1_data_gaussian.gif")

# %%
save("3_1_data_gaussian.jld2", "result", result)

# %% [markdown]
# # 2. Deterministic (Mean) Prediction

# %%
include("$(@__DIR__)/../scripts/default_params/params_data_gaussian.jl");

deterministic = true;
num_samples = 1;

include("$(@__DIR__)/../scripts/parameter_setup.jl");

# %%
scene_loader, controller, w_init, measurement_schedule, target_trajectory, target_speed =
controller_setup(scene_param,
                 predictor_param,
                 prediction_device=prediction_device,
                 cost_param=cost_param,
                 cnt_param=cnt_param,
                 dtc=dtc,
                 ado_vel_dict=ado_vel_dict,
                 ego_pos_init_vec=ego_pos_init_vec,
                 ego_pos_goal_vec=ego_pos_goal_vec,
                 target_speed=target_speed,
                 sim_horizon=sim_horizon,
                 verbose=true);
# Out:
# Scene Mode: data
# Prediction Mode: gaussian
# Deterministic Prediction: true
# Loaded evaluation data from /home/haruki/Documents/2020-21_Autumn/RiskSensitiveSAC.jl/Trajectron-plus-plus/experiments/processed/eth_test.pkl
# Looking at the eth_test.pkl sequence, data_id 0, start_idx 905

# %%
result, ~, ~ = evaluate(scene_loader, controller, w_init, ego_pos_goal_vec,
                  target_speed, measurement_schedule, target_trajectory,
                  pos_error_replan, nominal_control=false);

# %%
display_log(result.log)
# Out:
# Time 0.00 [sec]: New prediction is available to the controller.
# Time 0.00 [sec]: New SAC control computation is scheduled.
# Time 0.00 [sec]: New SAC control is available to the controller.
# Time 0.00 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.02 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.04 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.06 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.08 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.10 [sec]: New SAC control computation is scheduled.
# Time 0.10 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.12 [sec]: New SAC control is available to the controller.
# Time 0.12 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.14 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.16 [sec]: Control: [0.22051385045051575, -0.2956570088863373] is applied to the system.
# Time 0.18 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.20 [sec]: New SAC control computation is scheduled.
# Time 0.20 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.22 [sec]: New SAC control is available to the controller.
# Time 0.22 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.24 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.26 [sec]: Control: [0.19531354308128357, -0.24578122794628143] is applied to the system.
# Time 0.28 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.30 [sec]: New SAC control computation is scheduled.
# Time 0.30 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.32 [sec]: New SAC control is available to the controller.
# Time 0.32 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.34 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.36 [sec]: Control: [0.1992165893316269, -0.2320381999015808] is applied to the system.
# Time 0.38 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.40 [sec]: New measurement is obtained.
# Time 0.40 [sec]: New prediction is scheduled.
# Time 0.40 [sec]: New SAC control computation is scheduled.
# Time 0.40 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.42 [sec]: New prediction is available to the controller.
# Time 0.42 [sec]: New SAC control is available to the controller.
# Time 0.42 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.44 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.46 [sec]: Control: [0.21633510291576385, -0.23153726756572723] is applied to the system.
# Time 0.48 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.50 [sec]: New SAC control computation is scheduled.
# Time 0.50 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.52 [sec]: New SAC control is available to the controller.
# Time 0.52 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.54 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.56 [sec]: Control: [-0.6231920719146729, 0.7566541433334351] is applied to the system.
# Time 0.58 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.60 [sec]: New SAC control computation is scheduled.
# Time 0.60 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.62 [sec]: New SAC control is available to the controller.
# Time 0.62 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.64 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.66 [sec]: Control: [-0.19053807854652405, 0.23426935076713562] is applied to the system.
# Time 0.68 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.70 [sec]: New SAC control computation is scheduled.
# Time 0.70 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.72 [sec]: New SAC control is available to the controller.
# Time 0.72 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.74 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.76 [sec]: Control: [-0.054510556161403656, 0.07033441960811615] is applied to the system.
# Time 0.78 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.80 [sec]: New measurement is obtained.
# Time 0.80 [sec]: New prediction is scheduled.
# Time 0.80 [sec]: New SAC control computation is scheduled.
# Time 0.80 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.82 [sec]: New prediction is available to the controller.
# Time 0.82 [sec]: New SAC control is available to the controller.
# Time 0.82 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.84 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.86 [sec]: Control: [-0.012073665857315063, 0.019161924719810486] is applied to the system.
# Time 0.88 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.90 [sec]: New SAC control computation is scheduled.
# Time 0.90 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.92 [sec]: New SAC control is available to the controller.
# Time 0.92 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.94 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 0.96 [sec]: Control: [-0.015242119319736958, 0.008433770388364792] is applied to the system.
# Time 0.98 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.00 [sec]: New SAC control computation is scheduled.
# Time 1.00 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.02 [sec]: New SAC control is available to the controller.
# Time 1.02 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.04 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.06 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.08 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.10 [sec]: New SAC control computation is scheduled.
# Time 1.10 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.12 [sec]: New SAC control is available to the controller.
# Time 1.12 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.14 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.16 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.18 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.20 [sec]: New measurement is obtained.
# Time 1.20 [sec]: New prediction is scheduled.
# Time 1.20 [sec]: New SAC control computation is scheduled.
# Time 1.20 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.22 [sec]: New prediction is available to the controller.
# Time 1.22 [sec]: New SAC control is available to the controller.
# Time 1.22 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.24 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.26 [sec]: Control: [-0.0030578274745494127, 0.002056373283267021] is applied to the system.
# Time 1.28 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.30 [sec]: New SAC control computation is scheduled.
# Time 1.30 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.32 [sec]: New SAC control is available to the controller.
# Time 1.32 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.34 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.36 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.38 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.40 [sec]: New SAC control computation is scheduled.
# Time 1.40 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.42 [sec]: New SAC control is available to the controller.
# Time 1.42 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.44 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.46 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.48 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.50 [sec]: New SAC control computation is scheduled.
# Time 1.50 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.52 [sec]: New SAC control is available to the controller.
# Time 1.52 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.54 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.56 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.58 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.60 [sec]: New measurement is obtained.
# Time 1.60 [sec]: New prediction is scheduled.
# Time 1.60 [sec]: New SAC control computation is scheduled.
# Time 1.60 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.62 [sec]: New prediction is available to the controller.
# Time 1.62 [sec]: New SAC control is available to the controller.
# Time 1.62 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.64 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.66 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.68 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.70 [sec]: New SAC control computation is scheduled.
# Time 1.70 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.72 [sec]: New SAC control is available to the controller.
# Time 1.72 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.74 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.76 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.78 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.80 [sec]: New SAC control computation is scheduled.
# Time 1.80 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.82 [sec]: New SAC control is available to the controller.
# Time 1.82 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.84 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.86 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.88 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.90 [sec]: New SAC control computation is scheduled.
# Time 1.90 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.92 [sec]: New SAC control is available to the controller.
# Time 1.92 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.94 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.96 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.98 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.00 [sec]: New measurement is obtained.
# Time 2.00 [sec]: New prediction is scheduled.
# Time 2.00 [sec]: New SAC control computation is scheduled.
# Time 2.00 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.02 [sec]: New prediction is available to the controller.
# Time 2.02 [sec]: New SAC control is available to the controller.
# Time 2.02 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.04 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.06 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.08 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.10 [sec]: New SAC control computation is scheduled.
# Time 2.10 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.12 [sec]: New SAC control is available to the controller.
# Time 2.12 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.14 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.16 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.18 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.20 [sec]: New SAC control computation is scheduled.
# Time 2.20 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.22 [sec]: New SAC control is available to the controller.
# Time 2.22 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.24 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.26 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.28 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.30 [sec]: New SAC control computation is scheduled.
# Time 2.30 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.32 [sec]: New SAC control is available to the controller.
# Time 2.32 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.34 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.36 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.38 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.40 [sec]: New measurement is obtained.
# Time 2.40 [sec]: New prediction is scheduled.
# Time 2.40 [sec]: New SAC control computation is scheduled.
# Time 2.40 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.42 [sec]: New prediction is available to the controller.
# Time 2.42 [sec]: New SAC control is available to the controller.
# Time 2.42 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.44 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.46 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.48 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.50 [sec]: New SAC control computation is scheduled.
# Time 2.50 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.52 [sec]: New SAC control is available to the controller.
# Time 2.52 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.54 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.56 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.58 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.60 [sec]: New SAC control computation is scheduled.
# Time 2.60 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.62 [sec]: New SAC control is available to the controller.
# Time 2.62 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.64 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.66 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.68 [sec]: Control: [0.0011970651103183627, -0.0014937889063730836] is applied to the system.
# Time 2.70 [sec]: New SAC control computation is scheduled.
# Time 2.70 [sec]: Control: [0.0011970651103183627, -0.0014937889063730836] is applied to the system.
# Time 2.72 [sec]: New SAC control is available to the controller.
# Time 2.72 [sec]: Control: [0.0011970651103183627, -0.0014937889063730836] is applied to the system.
# Time 2.74 [sec]: Control: [0.0013618634548038244, -0.0018545215716585517] is applied to the system.
# Time 2.76 [sec]: Control: [0.006551481783390045, -0.009829246439039707] is applied to the system.
# Time 2.78 [sec]: Control: [0.00040678848745301366, -0.0004977543139830232] is applied to the system.
# Time 2.80 [sec]: New measurement is obtained.
# Time 2.80 [sec]: New prediction is scheduled.
# Time 2.80 [sec]: New SAC control computation is scheduled.
# Time 2.80 [sec]: Control: [0.006575554143637419, -0.00843396969139576] is applied to the system.
# Time 2.82 [sec]: New prediction is available to the controller.
# Time 2.82 [sec]: New SAC control is available to the controller.
# Time 2.82 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.84 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.86 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.88 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.90 [sec]: New SAC control computation is scheduled.
# Time 2.90 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.92 [sec]: New SAC control is available to the controller.
# Time 2.92 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.94 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.96 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.98 [sec]: Control: [-0.00016911278362385929, 0.00019321241416037083] is applied to the system.
# Time 3.00 [sec]: New SAC control computation is scheduled.
# Time 3.00 [sec]: Control: [0.003748806659132242, -0.006525748874992132] is applied to the system.
# Time 3.02 [sec]: New SAC control is available to the controller.
# Time 3.02 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.04 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.06 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.08 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.10 [sec]: New SAC control computation is scheduled.
# Time 3.10 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.12 [sec]: New SAC control is available to the controller.
# Time 3.12 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.14 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.16 [sec]: Control: [-0.00012011497165076435, 0.0001385299547109753] is applied to the system.
# Time 3.18 [sec]: Control: [0.004523939453065395, -0.00621954258531332] is applied to the system.
# Time 3.20 [sec]: New measurement is obtained.
# Time 3.20 [sec]: New prediction is scheduled.
# Time 3.20 [sec]: New SAC control computation is scheduled.
# Time 3.20 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.22 [sec]: New prediction is available to the controller.
# Time 3.22 [sec]: New SAC control is available to the controller.
# Time 3.22 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.24 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.26 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.28 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.30 [sec]: New SAC control computation is scheduled.
# Time 3.30 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.32 [sec]: New SAC control is available to the controller.
# Time 3.32 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.34 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.36 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.38 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.40 [sec]: New SAC control computation is scheduled.
# Time 3.40 [sec]: Control: [-0.00017065989959519356, 0.00019896921003237367] is applied to the system.
# Time 3.42 [sec]: New SAC control is available to the controller.
# Time 3.42 [sec]: Control: [0.003672787919640541, -0.004842106718569994] is applied to the system.
# Time 3.44 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.46 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.48 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.50 [sec]: New SAC control computation is scheduled.
# Time 3.50 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.52 [sec]: New SAC control is available to the controller.
# Time 3.52 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.54 [sec]: Control: [0.0004349845985416323, -0.0005091949133202434] is applied to the system.
# Time 3.56 [sec]: Control: [0.004260088317096233, -0.005219277460128069] is applied to the system.
# Time 3.58 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.60 [sec]: New measurement is obtained.
# Time 3.60 [sec]: New prediction is scheduled.
# Time 3.60 [sec]: New SAC control computation is scheduled.
# Time 3.60 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.62 [sec]: New prediction is available to the controller.
# Time 3.62 [sec]: New SAC control is available to the controller.
# Time 3.62 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.64 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.66 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.68 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.70 [sec]: New SAC control computation is scheduled.
# Time 3.70 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.72 [sec]: New SAC control is available to the controller.
# Time 3.72 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.74 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.76 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.78 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.80 [sec]: New SAC control computation is scheduled.
# Time 3.80 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.82 [sec]: New SAC control is available to the controller.
# Time 3.82 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.84 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.86 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.88 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.90 [sec]: New SAC control computation is scheduled.
# Time 3.90 [sec]: Control: [0.0004522032104432583, -0.0005277206073515117] is applied to the system.
# Time 3.92 [sec]: New SAC control is available to the controller.
# Time 3.92 [sec]: Control: [0.004078526981174946, -0.004805190488696098] is applied to the system.
# Time 3.94 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.96 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.98 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.00 [sec]: New measurement is obtained.
# Time 4.00 [sec]: New prediction is scheduled.
# Time 4.00 [sec]: New SAC control computation is scheduled.
# Time 4.00 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.02 [sec]: New prediction is available to the controller.
# Time 4.02 [sec]: New SAC control is available to the controller.
# Time 4.02 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.04 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.06 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.08 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.10 [sec]: New SAC control computation is scheduled.
# Time 4.10 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.12 [sec]: New SAC control is available to the controller.
# Time 4.12 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.14 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.16 [sec]: Control: [-0.19260640442371368, -0.010352798737585545] is applied to the system.
# Time 4.18 [sec]: Control: [0.0036467770114541054, -0.004260552115738392] is applied to the system.
# Time 4.20 [sec]: New SAC control computation is scheduled.
# Time 4.20 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.22 [sec]: New SAC control is available to the controller.
# Time 4.22 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.24 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.26 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.28 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.30 [sec]: New SAC control computation is scheduled.
# Time 4.30 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.32 [sec]: New SAC control is available to the controller.
# Time 4.32 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.34 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.36 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.38 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.40 [sec]: New measurement is obtained.
# Time 4.40 [sec]: New prediction is scheduled.
# Time 4.40 [sec]: New SAC control computation is scheduled.
# Time 4.40 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.42 [sec]: New prediction is available to the controller.
# Time 4.42 [sec]: New SAC control is available to the controller.
# Time 4.42 [sec]: Control: [-0.03141915425658226, -0.00018321220704820007] is applied to the system.
# Time 4.44 [sec]: Control: [0.003042380092665553, -0.0035436113830655813] is applied to the system.
# Time 4.46 [sec]: Control: [0.010091454721987247, 0.0026030640583485365] is applied to the system.
# Time 4.48 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.50 [sec]: New SAC control computation is scheduled.
# Time 4.50 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.52 [sec]: New SAC control is available to the controller.
# Time 4.52 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.54 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.56 [sec]: Control: [-4.999997138977051, -0.005557080265134573] is applied to the system.
# Time 4.58 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.60 [sec]: New SAC control computation is scheduled.
# Time 4.60 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.62 [sec]: New SAC control is available to the controller.
# Time 4.62 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.64 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.66 [sec]: Control: [-0.987382709980011, -0.15835219621658325] is applied to the system.
# Time 4.68 [sec]: Control: [0.0026196029502898455, -0.0030537189450114965] is applied to the system.
# Time 4.70 [sec]: New SAC control computation is scheduled.
# Time 4.70 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.72 [sec]: New SAC control is available to the controller.
# Time 4.72 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.74 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.76 [sec]: Control: [-0.4691491425037384, -0.17291352152824402] is applied to the system.
# Time 4.78 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.80 [sec]: New measurement is obtained.
# Time 4.80 [sec]: New prediction is scheduled.
# Time 4.80 [sec]: New SAC control computation is scheduled.
# Time 4.80 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.82 [sec]: New prediction is available to the controller.
# Time 4.82 [sec]: New SAC control is available to the controller.
# Time 4.82 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.84 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.86 [sec]: Control: [0.07476285845041275, -0.45497745275497437] is applied to the system.
# Time 4.88 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 4.90 [sec]: New SAC control computation is scheduled.
# Time 4.90 [sec]: Control: [1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 4.92 [sec]: New SAC control is available to the controller.
# Time 4.92 [sec]: Control: [1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 4.94 [sec]: Control: [1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 4.96 [sec]: Control: [-2.3467886447906494, 3.2392256259918213] is applied to the system.
# Time 4.98 [sec]: Control: [1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 5.00 [sec]: New SAC control computation is scheduled.
# Time 5.00 [sec]: Control: [1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 5.02 [sec]: New SAC control is available to the controller.
# Time 5.02 [sec]: Control: [1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 5.04 [sec]: Control: [1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 5.06 [sec]: Control: [1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 5.08 [sec]: Control: [1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 5.10 [sec]: New SAC control computation is scheduled.
# Time 5.10 [sec]: Control: [1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 5.12 [sec]: New SAC control is available to the controller.
# Time 5.12 [sec]: Control: [1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 5.14 [sec]: Control: [1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 5.16 [sec]: Control: [1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 5.18 [sec]: Control: [1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 5.20 [sec]: New measurement is obtained.
# Time 5.20 [sec]: New prediction is scheduled.
# Time 5.20 [sec]: New SAC control computation is scheduled.
# Time 5.20 [sec]: Control: [1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 5.22 [sec]: New prediction is available to the controller.
# Time 5.22 [sec]: New SAC control is available to the controller.
# Time 5.22 [sec]: Control: [1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 5.24 [sec]: Control: [1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 5.26 [sec]: Control: [1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 5.28 [sec]: Control: [0.5203275680541992, -1.931128978729248] is applied to the system.
# Time 5.30 [sec]: New SAC control computation is scheduled.
# Time 5.30 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.32 [sec]: New SAC control is available to the controller.
# Time 5.32 [sec]: Control: [0.0010251370258629322, -0.0011958631221204996] is applied to the system.
# Time 5.34 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.36 [sec]: Control: [-2.108145236968994, 3.3993711471557617] is applied to the system.
# Time 5.38 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.40 [sec]: New SAC control computation is scheduled.
# Time 5.40 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.42 [sec]: New SAC control is available to the controller.
# Time 5.42 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.44 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.46 [sec]: Control: [0.2846668064594269, 1.9796375036239624] is applied to the system.
# Time 5.48 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.50 [sec]: New SAC control computation is scheduled.
# Time 5.50 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.52 [sec]: New SAC control is available to the controller.
# Time 5.52 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.54 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.56 [sec]: Control: [0.9818918704986572, 0.18944236636161804] is applied to the system.
# Time 5.58 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.60 [sec]: New measurement is obtained.
# Time 5.60 [sec]: New prediction is scheduled.
# Time 5.60 [sec]: New SAC control computation is scheduled.
# Time 5.60 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.62 [sec]: New prediction is available to the controller.
# Time 5.62 [sec]: New SAC control is available to the controller.
# Time 5.62 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.64 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.66 [sec]: Control: [0.2005452960729599, 1.9899200201034546] is applied to the system.
# Time 5.68 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.70 [sec]: New SAC control computation is scheduled.
# Time 5.70 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.72 [sec]: New SAC control is available to the controller.
# Time 5.72 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.74 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.76 [sec]: Control: [-3.2316789627075195, 3.815265417098999] is applied to the system.
# Time 5.78 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.80 [sec]: New SAC control computation is scheduled.
# Time 5.80 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.82 [sec]: New SAC control is available to the controller.
# Time 5.82 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.84 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.86 [sec]: Control: [-1.2235827445983887, 1.5820382833480835] is applied to the system.
# Time 5.88 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.90 [sec]: New SAC control computation is scheduled.
# Time 5.90 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.92 [sec]: New SAC control is available to the controller.
# Time 5.92 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.94 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 5.96 [sec]: Control: [1.517215609550476, 1.3030949831008911] is applied to the system.
# Time 5.98 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 6.00 [sec]: New measurement is obtained.
# Time 6.00 [sec]: New prediction is scheduled.
# Time 6.00 [sec]: New SAC control computation is scheduled.
# Time 6.00 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 6.02 [sec]: New prediction is available to the controller.
# Time 6.02 [sec]: New SAC control is available to the controller.
# Time 6.02 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 6.04 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 6.06 [sec]: Control: [-0.05396490544080734, 0.19300875067710876] is applied to the system.
# Time 6.08 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 6.10 [sec]: New SAC control computation is scheduled.
# Time 6.10 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 6.12 [sec]: New SAC control is available to the controller.
# Time 6.12 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 6.14 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 6.16 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 6.18 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 6.20 [sec]: New SAC control computation is scheduled.
# Time 6.20 [sec]: Control: [-4.792210102081299, 1.4264363050460815] is applied to the system.
# Time 6.22 [sec]: New SAC control is available to the controller.
# Time 6.22 [sec]: Control: [-4.792210102081299, 1.4264363050460815] is applied to the system.
# Time 6.24 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 6.26 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 6.28 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 6.30 [sec]: New SAC control computation is scheduled.
# Time 6.30 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 6.32 [sec]: New SAC control is available to the controller.
# Time 6.32 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 6.34 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 6.36 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 6.38 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 6.40 [sec]: New measurement is obtained.
# Time 6.40 [sec]: New prediction is scheduled.
# Time 6.40 [sec]: New SAC control computation is scheduled.
# Time 6.40 [sec]: Control: [-3.610656976699829, -3.4587795734405518] is applied to the system.
# Time 6.42 [sec]: New prediction is available to the controller.
# Time 6.42 [sec]: New SAC control is available to the controller.
# Time 6.42 [sec]: Control: [-3.610656976699829, -3.4587795734405518] is applied to the system.
# Time 6.44 [sec]: Control: [-3.610656976699829, -3.4587795734405518] is applied to the system.
# Time 6.46 [sec]: Control: [-3.610656976699829, -3.4587795734405518] is applied to the system.
# Time 6.48 [sec]: Control: [1.0471376180648804, -1.703966736793518] is applied to the system.
# Time 6.50 [sec]: New SAC control computation is scheduled.
# Time 6.50 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 6.52 [sec]: New SAC control is available to the controller.
# Time 6.52 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 6.54 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 6.56 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 6.58 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 6.60 [sec]: New SAC control computation is scheduled.
# Time 6.60 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 6.62 [sec]: New SAC control is available to the controller.
# Time 6.62 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 6.64 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 6.66 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 6.68 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 6.70 [sec]: New SAC control computation is scheduled.
# Time 6.70 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 6.72 [sec]: New SAC control is available to the controller.
# Time 6.72 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 6.74 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 6.76 [sec]: Control: [2.1605122089385986, -3.3663313388824463] is applied to the system.
# Time 6.78 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 6.80 [sec]: New measurement is obtained.
# Time 6.80 [sec]: New prediction is scheduled.
# Time 6.80 [sec]: New SAC control computation is scheduled.
# Time 6.80 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 6.82 [sec]: New prediction is available to the controller.
# Time 6.82 [sec]: New SAC control is available to the controller.
# Time 6.82 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 6.84 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 6.86 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 6.88 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 6.90 [sec]: New SAC control computation is scheduled.
# Time 6.90 [sec]: Control: [-2.828429937362671, -2.828429937362671] is applied to the system.
# Time 6.92 [sec]: New SAC control is available to the controller.
# Time 6.92 [sec]: Control: [-2.828429937362671, -2.828429937362671] is applied to the system.
# Time 6.94 [sec]: Control: [-2.828429937362671, -2.828429937362671] is applied to the system.
# Time 6.96 [sec]: Control: [-2.828429937362671, -2.828429937362671] is applied to the system.
# Time 6.98 [sec]: Control: [-2.828429937362671, -2.828429937362671] is applied to the system.
# Time 7.00 [sec]: New SAC control computation is scheduled.
# Time 7.00 [sec]: Control: [-2.828429937362671, -2.828429937362671] is applied to the system.
# Time 7.02 [sec]: New SAC control is available to the controller.
# Time 7.02 [sec]: Control: [-2.828429937362671, -2.828429937362671] is applied to the system.
# Time 7.04 [sec]: Control: [-2.828429937362671, -2.828429937362671] is applied to the system.
# Time 7.06 [sec]: Control: [-2.828429937362671, -2.828429937362671] is applied to the system.
# Time 7.08 [sec]: Control: [-2.828429937362671, -2.828429937362671] is applied to the system.
# Time 7.10 [sec]: New SAC control computation is scheduled.
# Time 7.10 [sec]: Control: [-2.828429937362671, -2.828429937362671] is applied to the system.
# Time 7.12 [sec]: New SAC control is available to the controller.
# Time 7.12 [sec]: Control: [-2.828429937362671, -2.828429937362671] is applied to the system.
# Time 7.14 [sec]: Control: [-2.828429937362671, -2.828429937362671] is applied to the system.
# Time 7.16 [sec]: Control: [-2.828429937362671, -2.828429937362671] is applied to the system.
# Time 7.18 [sec]: Control: [-2.828429937362671, -2.828429937362671] is applied to the system.
# Time 7.20 [sec]: New measurement is obtained.
# Time 7.20 [sec]: New prediction is scheduled.
# Time 7.20 [sec]: New SAC control computation is scheduled.
# Time 7.20 [sec]: Control: [-2.828429937362671, -2.828429937362671] is applied to the system.
# Time 7.22 [sec]: New prediction is available to the controller.
# Time 7.22 [sec]: New SAC control is available to the controller.
# Time 7.22 [sec]: Control: [-2.0309958457946777, -4.568922996520996] is applied to the system.
# Time 7.24 [sec]: Control: [-2.0309958457946777, -4.568922996520996] is applied to the system.
# Time 7.26 [sec]: Control: [-2.0309958457946777, -4.568922996520996] is applied to the system.
# Time 7.28 [sec]: Control: [-2.0309958457946777, -4.568922996520996] is applied to the system.
# Time 7.30 [sec]: New SAC control computation is scheduled.
# Time 7.30 [sec]: Control: [-1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 7.32 [sec]: New SAC control is available to the controller.
# Time 7.32 [sec]: Control: [-1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 7.34 [sec]: Control: [-1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 7.36 [sec]: Control: [-1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 7.38 [sec]: Control: [-1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 7.40 [sec]: New SAC control computation is scheduled.
# Time 7.40 [sec]: Control: [-1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 7.42 [sec]: New SAC control is available to the controller.
# Time 7.42 [sec]: Control: [-1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 7.44 [sec]: Control: [-1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 7.46 [sec]: Control: [-1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 7.48 [sec]: Control: [-1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 7.50 [sec]: New SAC control computation is scheduled.
# Time 7.50 [sec]: Control: [-1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 7.52 [sec]: New SAC control is available to the controller.
# Time 7.52 [sec]: Control: [-1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 7.54 [sec]: Control: [-1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 7.56 [sec]: Control: [-1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 7.58 [sec]: Control: [-1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 7.60 [sec]: New measurement is obtained.
# Time 7.60 [sec]: New prediction is scheduled.
# Time 7.60 [sec]: New SAC control computation is scheduled.
# Time 7.60 [sec]: Control: [-1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 7.62 [sec]: New prediction is available to the controller.
# Time 7.62 [sec]: New SAC control is available to the controller.
# Time 7.62 [sec]: Control: [-1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 7.64 [sec]: Control: [-1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 7.66 [sec]: Control: [-1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 7.68 [sec]: Control: [-1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 7.70 [sec]: New SAC control computation is scheduled.
# Time 7.70 [sec]: Control: [0.0, 4.0] is applied to the system.
# Time 7.72 [sec]: New SAC control is available to the controller.
# Time 7.72 [sec]: Control: [0.0, 4.0] is applied to the system.
# Time 7.74 [sec]: Control: [0.0, 4.0] is applied to the system.
# Time 7.76 [sec]: Control: [0.0, 4.0] is applied to the system.
# Time 7.78 [sec]: Control: [0.0, 4.0] is applied to the system.
# Time 7.80 [sec]: New SAC control computation is scheduled.
# Time 7.80 [sec]: Control: [0.0, 4.0] is applied to the system.
# Time 7.82 [sec]: New SAC control is available to the controller.
# Time 7.82 [sec]: Control: [0.0, 4.0] is applied to the system.
# Time 7.84 [sec]: Control: [0.0, 4.0] is applied to the system.
# Time 7.86 [sec]: Control: [0.0, 4.0] is applied to the system.
# Time 7.88 [sec]: Control: [0.0, 4.0] is applied to the system.
# Time 7.90 [sec]: New SAC control computation is scheduled.
# Time 7.90 [sec]: Control: [0.0, 4.0] is applied to the system.
# Time 7.92 [sec]: New SAC control is available to the controller.
# Time 7.92 [sec]: Control: [0.0, 4.0] is applied to the system.
# Time 7.94 [sec]: Control: [0.0, 4.0] is applied to the system.
# Time 7.96 [sec]: Position deviation: 2.0008. Target Trajectory is replanned.
# Time 7.96 [sec]: Control: [0.0, 4.0] is applied to the system.
# Time 7.98 [sec]: Control: [0.0, 4.0] is applied to the system.
# Time 8.00 [sec]: New measurement is obtained.
# Time 8.00 [sec]: New prediction is scheduled.
# Time 8.00 [sec]: New SAC control computation is scheduled.
# Time 8.00 [sec]: Control: [0.0, 4.0] is applied to the system.
# Time 8.02 [sec]: New prediction is available to the controller.
# Time 8.02 [sec]: New SAC control is available to the controller.
# Time 8.02 [sec]: Control: [0.0, 4.0] is applied to the system.
# Time 8.04 [sec]: Control: [0.0, 4.0] is applied to the system.
# Time 8.06 [sec]: Control: [0.0, 4.0] is applied to the system.
# Time 8.08 [sec]: Control: [3.2165169715881348, -3.828056812286377] is applied to the system.
# Time 8.10 [sec]: New SAC control computation is scheduled.
# Time 8.10 [sec]: Control: [-0.0, -2.0] is applied to the system.
# Time 8.12 [sec]: New SAC control is available to the controller.
# Time 8.12 [sec]: Control: [-0.0, -2.0] is applied to the system.
# Time 8.14 [sec]: Control: [-0.0, -2.0] is applied to the system.
# Time 8.16 [sec]: Control: [-0.0, -2.0] is applied to the system.
# Time 8.18 [sec]: Control: [-0.0, -2.0] is applied to the system.
# Time 8.20 [sec]: New SAC control computation is scheduled.
# Time 8.20 [sec]: Control: [-0.0, -2.0] is applied to the system.
# Time 8.22 [sec]: New SAC control is available to the controller.
# Time 8.22 [sec]: Control: [-0.0, -2.0] is applied to the system.
# Time 8.24 [sec]: Control: [4.693477630615234, 1.72373628616333] is applied to the system.
# Time 8.26 [sec]: Control: [4.693477630615234, 1.72373628616333] is applied to the system.
# Time 8.28 [sec]: Control: [-0.0, -2.0] is applied to the system.
# Time 8.30 [sec]: New SAC control computation is scheduled.
# Time 8.30 [sec]: Control: [-0.0, -2.0] is applied to the system.
# Time 8.32 [sec]: New SAC control is available to the controller.
# Time 8.32 [sec]: Control: [-0.0, -2.0] is applied to the system.
# Time 8.34 [sec]: Control: [-0.0, -2.0] is applied to the system.
# Time 8.36 [sec]: Control: [1.575939416885376, 1.2314280271530151] is applied to the system.
# Time 8.38 [sec]: Control: [-0.0, -2.0] is applied to the system.
# Time 8.40 [sec]: New measurement is obtained.
# Time 8.40 [sec]: New prediction is scheduled.
# Time 8.40 [sec]: New SAC control computation is scheduled.
# Time 8.40 [sec]: Control: [-0.0, -2.0] is applied to the system.
# Time 8.42 [sec]: New prediction is available to the controller.
# Time 8.42 [sec]: New SAC control is available to the controller.
# Time 8.42 [sec]: Control: [-0.0, -2.0] is applied to the system.
# Time 8.44 [sec]: Control: [-0.0, -2.0] is applied to the system.
# Time 8.46 [sec]: Control: [1.2177555561065674, 1.5865281820297241] is applied to the system.
# Time 8.48 [sec]: Control: [2.894843578338623, -2.76041316986084] is applied to the system.
# Time 8.50 [sec]: New SAC control computation is scheduled.
# Time 8.50 [sec]: Control: [-2.0, 0.0] is applied to the system.
# Time 8.52 [sec]: New SAC control is available to the controller.
# Time 8.52 [sec]: Control: [-2.0, 0.0] is applied to the system.
# Time 8.54 [sec]: Control: [4.6582350730896, 1.8168232440948486] is applied to the system.
# Time 8.56 [sec]: Control: [4.6582350730896, 1.8168232440948486] is applied to the system.
# Time 8.58 [sec]: Control: [-2.0, 0.0] is applied to the system.
# Time 8.60 [sec]: New SAC control computation is scheduled.
# Time 8.60 [sec]: Control: [-2.0, 0.0] is applied to the system.
# Time 8.62 [sec]: New SAC control is available to the controller.
# Time 8.62 [sec]: Control: [-2.0, 0.0] is applied to the system.
# Time 8.64 [sec]: Control: [-2.0, 0.0] is applied to the system.
# Time 8.66 [sec]: Control: [-2.0, 0.0] is applied to the system.
# Time 8.68 [sec]: Control: [-2.0, 0.0] is applied to the system.
# Time 8.70 [sec]: New SAC control computation is scheduled.
# Time 8.70 [sec]: Control: [-2.0, 0.0] is applied to the system.
# Time 8.72 [sec]: New SAC control is available to the controller.
# Time 8.72 [sec]: Control: [-2.0, 0.0] is applied to the system.
# Time 8.74 [sec]: Control: [-2.0, 0.0] is applied to the system.
# Time 8.76 [sec]: Control: [2.7253427505493164, -4.191957473754883] is applied to the system.
# Time 8.78 [sec]: Control: [-2.0, 0.0] is applied to the system.
# Time 8.80 [sec]: New measurement is obtained.
# Time 8.80 [sec]: New prediction is scheduled.
# Time 8.80 [sec]: New SAC control computation is scheduled.
# Time 8.80 [sec]: Control: [-2.0, 0.0] is applied to the system.
# Time 8.82 [sec]: New prediction is available to the controller.
# Time 8.82 [sec]: New SAC control is available to the controller.
# Time 8.82 [sec]: Control: [-2.0, 0.0] is applied to the system.
# Time 8.84 [sec]: Control: [-2.0, 0.0] is applied to the system.
# Time 8.86 [sec]: Control: [-2.0, 0.0] is applied to the system.
# Time 8.88 [sec]: Control: [-2.0, 0.0] is applied to the system.
# Time 8.90 [sec]: New SAC control computation is scheduled.
# Time 8.90 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.92 [sec]: New SAC control is available to the controller.
# Time 8.92 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.94 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 8.96 [sec]: Control: [3.779660701751709, 3.273249864578247] is applied to the system.
# Time 8.98 [sec]: Control: [3.779660701751709, 3.273249864578247] is applied to the system.
# Time 9.00 [sec]: New SAC control computation is scheduled.
# Time 9.00 [sec]: Control: [-1.3529841899871826, -1.4728997945785522] is applied to the system.
# Time 9.02 [sec]: New SAC control is available to the controller.
# Time 9.02 [sec]: Control: [3.8211734294891357, 3.224691390991211] is applied to the system.
# Time 9.04 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.06 [sec]: Control: [3.7071664333343506, 3.355132818222046] is applied to the system.
# Time 9.08 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.10 [sec]: New SAC control computation is scheduled.
# Time 9.10 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.12 [sec]: New SAC control is available to the controller.
# Time 9.12 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.14 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.16 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.18 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.20 [sec]: New measurement is obtained.
# Time 9.20 [sec]: New prediction is scheduled.
# Time 9.20 [sec]: New SAC control computation is scheduled.
# Time 9.20 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.22 [sec]: New prediction is available to the controller.
# Time 9.22 [sec]: New SAC control is available to the controller.
# Time 9.22 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.24 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.26 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.28 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.30 [sec]: New SAC control computation is scheduled.
# Time 9.30 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.32 [sec]: New SAC control is available to the controller.
# Time 9.32 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.34 [sec]: Control: [4.533014297485352, 2.10992431640625] is applied to the system.
# Time 9.36 [sec]: Control: [4.533014297485352, 2.10992431640625] is applied to the system.
# Time 9.38 [sec]: Control: [4.533014297485352, 2.10992431640625] is applied to the system.
# Time 9.40 [sec]: New SAC control computation is scheduled.
# Time 9.40 [sec]: Control: [4.533014297485352, 2.10992431640625] is applied to the system.
# Time 9.42 [sec]: New SAC control is available to the controller.
# Time 9.42 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.44 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.46 [sec]: Control: [-1.9557372331619263, -0.4184398055076599] is applied to the system.
# Time 9.48 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.50 [sec]: New SAC control computation is scheduled.
# Time 9.50 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.52 [sec]: New SAC control is available to the controller.
# Time 9.52 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.54 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.56 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.58 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.60 [sec]: New measurement is obtained.
# Time 9.60 [sec]: New prediction is scheduled.
# Time 9.60 [sec]: New SAC control computation is scheduled.
# Time 9.60 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.62 [sec]: New prediction is available to the controller.
# Time 9.62 [sec]: New SAC control is available to the controller.
# Time 9.62 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.64 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.66 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.68 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.70 [sec]: New SAC control computation is scheduled.
# Time 9.70 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.72 [sec]: New SAC control is available to the controller.
# Time 9.72 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.74 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.76 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.78 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.80 [sec]: New SAC control computation is scheduled.
# Time 9.80 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.82 [sec]: New SAC control is available to the controller.
# Time 9.82 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.84 [sec]: Control: [-0.9641156196594238, -0.3099854588508606] is applied to the system.
# Time 9.86 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.88 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.90 [sec]: New SAC control computation is scheduled.
# Time 9.90 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.92 [sec]: New SAC control is available to the controller.
# Time 9.92 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.94 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.96 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 9.98 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 10.00 [sec]: New measurement is obtained.

# %%
result.total_cnt_cost
# Out:
# 3.454112698190509

# %%
result.total_pos_cost
# Out:
# 0.7869322586734754

# %%
result.total_col_cost
# Out:
# 70.06366003780634

# %%
result.total_cnt_cost + result.total_pos_cost + result.total_col_cost
# Out:
# 74.30470499467033

# %%
minimum([minimum(vcat([norm(get_position(w.e_state) - ap) for ap in values(w.ap_dict)], Inf))
                          for w in result.w_history])
# Out:
# 0.3053163186110886

# %%
make_gif(result, dtplot=0.02, fps=50, xlim=(-3. + -5.263534, 13. + -5.263534), 
         ylim=(0. + -5.314636, 10. + -5.314636), figsize=(600, 400), 
         legendfontsize=7, legend=:bottomright, markersize=5., filename="3_2_data_gaussian_deterministic.gif")
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:20
# ┌ Info: Saved animation to
# │   fn = /home/haruki/Documents/2020-21_Autumn/RiskSensitiveSAC.jl/notebook/3_2_data_gaussian_deterministic.gif
# └ @ Plots /home/haruki/.julia/packages/Plots/qZHsp/src/animation.jl:98
# Plots.AnimatedGif("/home/haruki/Documents/2020-21_Autumn/RiskSensitiveSAC.jl/notebook/3_2_data_gaussian_deterministic.gif")

# %%
save("3_2_data_gaussian_deterministic.jld2", "result", result)
